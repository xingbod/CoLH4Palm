# %%
from __future__ import division
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '1'
import time
import argparse
import torch
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import torch.nn.functional as F
from utils import accuracy, AverageMeter, save_checkpoint, visualize_graph, get_parameters_size
from torch.utils.tensorboard import SummaryWriter
from net_factory import get_network_fn


# dataset
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.nn import DataParallel
import tqdm
import numpy as np
# del test_loader
import tqdm
# test_loader

# %%
parser = argparse.ArgumentParser(description='PyTorch GCN MNIST Training')

parser.add_argument('--epochs', default=50, type=int, metavar='N',
                    help='number of total epochs to run')
parser.add_argument('-j', '--workers', default=4, type=int, metavar='N',
                    help='number of data loading workers (default: 4)')
parser.add_argument('--start-epoch', default=0, type=int, metavar='N',
                    help='manual epoch number (useful on restarts)')
parser.add_argument('-b', '--batch-size', default=128, type=int,
                    metavar='N', help='mini-batch size (default: 64)')
parser.add_argument('--lr', '--learning-rate', default=0.01, type=float,
                    metavar='LR', help='initial learning rate')
parser.add_argument('--momentum', default=0.9, type=float, metavar='M',
                    help='momentum')
parser.add_argument('--print-freq', '-p', default=10, type=int,
                    metavar='N', help='print frequency (default: 10)')
parser.add_argument('--resume', default='', type=str, metavar='PATH',
                    help='path to latest checkpoint (default: none)')
parser.add_argument('--pretrained', default='', type=str, metavar='PATH',
                    help='path to pretrained checkpoint (default: none)')
parser.add_argument('--gpu', default=0, type=int,
                    metavar='N', help='GPU device ID (default: -1)')
parser.add_argument('--dataset_dir', default='../../MNIST', type=str, metavar='PATH',
                    help='path to dataset (default: ../MNIST)')
parser.add_argument('--comment', default='', type=str, metavar='INFO',
                    help='Extra description for tensorboard')
parser.add_argument('--model', default='gcn', type=str, metavar='NETWORK',
                    help='Network to train')

args = parser.parse_args(args=[])

use_cuda = (args.gpu >= 0) and torch.cuda.is_available()
best_prec1 = 0
writer = SummaryWriter(comment='_'+args.model+'_'+args.comment)
iteration = 0

# # from loaddataset import load_data
# from loaddataset import load_data

# batch_size = 64
# train_loader = DataLoader(load_data(training=True), batch_size=batch_size, shuffle=True)  # ,prefetch_factor=2
# test_loader = DataLoader(load_data(training=False), batch_size=batch_size, shuffle=True)  # ,prefetch_factor=2

# %%
# Load model
model = get_network_fn(name='GCN2wayHashingsimple2')#GCNCNN
# print(model)

# Try to visulize the model
try:
	visualize_graph(model, writer, input_size=(1, 5, 128, 128))
except:
	print('\nNetwork Visualization Failed! But the training procedure continue.')
# Out:
# /root/autodl-nas/Gabor_CNN_PyTorch/gcn/layers/GConv.py:67: TracerWarning: Converting a tensor to a Python index might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   for i in range(x.size(1)):
# /root/autodl-nas/Gabor_CNN_PyTorch/demo/net_factory.py:194: TracerWarning: Converting a tensor to a Python index might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   return x + self.pe[:, :, :x.size(2), :x.size(3)]

# %%
# out = model(torch.rand(5, 5, 128, 128))
# print(out.size())

# %%
# # Calculate the total parameters of the model
# print('Model size: {:0.2f} million float parameters'.format(get_parameters_size(model)/1e6))
# args.pretrained = 'model_best_gcn2waycqhashing.pth.tar'
# if os.path.isfile(args.pretrained):
#     print("=> loading checkpoint '{}'".format(args.pretrained))
#     checkpoint = torch.load(args.pretrained,map_location=torch.device('cpu'))
#     model.load_state_dict(checkpoint['state_dict'])
# else:
#     print("=> no checkpoint found at '{}'".format(args.pretrained))
# print(checkpoint['best_prec1'])

# %%
class CSQLoss(torch.nn.Module):
    def __init__(self, config, bit):
        super(CSQLoss, self).__init__()
        self.is_single_label = config["dataset"] not in {"nuswide_21", "nuswide_21_m", "coco"}
        self.hash_targets = self.get_hash_targets(config["n_class"], bit).to(config["device"])
        self.multi_label_random_center = torch.randint(2, (bit,)).float().to(config["device"])
        self.criterion = torch.nn.BCELoss().to(config["device"])

    def forward(self, u, y, ind, config):
        u = u.tanh()
        hash_center = self.label2center(y)
        center_loss = self.criterion(0.5 * (u + 1), 0.5 * (hash_center + 1))

        Q_loss = (u.abs() - 1).pow(2).mean()
        return center_loss + config["lambda"] * Q_loss

    def label2center(self, y):
        if self.is_single_label:
            hash_center = self.hash_targets[y.argmax(axis=1)]
        else:
            # to get sign no need to use mean, use sum here
            center_sum = y @ self.hash_targets
            random_center = self.multi_label_random_center.repeat(center_sum.shape[0], 1)
            center_sum[center_sum == 0] = random_center[center_sum == 0]
            hash_center = 2 * (center_sum > 0).float() - 1
        return hash_center

    # use algorithm 1 to generate hash centers
    def get_hash_targets(self, n_class, bit):
        H_K = hadamard(bit)
        H_2K = np.concatenate((H_K, -H_K), 0)
        hash_targets = torch.from_numpy(H_2K[:n_class]).float()

        if H_2K.shape[0] < n_class:
            hash_targets.resize_(n_class, bit)
            for k in range(20):
                for index in range(H_2K.shape[0], n_class):
                    ones = torch.ones(bit)
                    # Bernouli distribution
                    sa = random.sample(list(range(bit)), bit // 2)
                    ones[sa] = -1
                    hash_targets[index] = ones
                # to find average/min  pairwise distance
                c = []
                for i in range(n_class):
                    for j in range(n_class):
                        if i < j:
                            TF = sum(hash_targets[i] != hash_targets[j])
                            c.append(TF)
                c = np.array(c)

                # choose min(c) in the range of K/4 to K/3
                # see in https://github.com/yuanli2333/Hadamard-Matrix-for-hashing/issues/1
                # but it is hard when bit is  small
                if c.min() > bit / 4 and c.mean() >= bit / 2:
                    print(c.min(), c.mean())
                    break
        return hash_targets

# %%
# from torchvision import datasets, models, transforms

# model = models.resnet18(pretrained=True)
# num_ftrs = model.fc.in_features
# # Here the size of each output sample is set to 2.
# # Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
# model.fc = nn.Linear(num_ftrs, 450)

# %%
import numpy as np
import os
# import cv2
from  matplotlib import pyplot as plt

## torch
import torch
import torch.nn as nn
import torch.nn.functional as F
# from torchsummary import summary

# dataset
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.nn import DataParallel
import tqdm


# read image
import PIL
from PIL import Image
from utils import *

ms_polyu_path = 'dataset/MS_PolyU/'
casia_path = 'dataset/CASIA-Multi-Spectral-PalmprintV1/images/'

r_img_path = ms_polyu_path + 'Red_ind/'
b_img_path =  ms_polyu_path + 'Blue_ind/'
n_img_path =  ms_polyu_path + 'NIR_ind/'
g_img_path =  ms_polyu_path + 'Green_ind/'

################ DATASET CLASS
def one_hot_embedding(labels, num_classes):
    """Embedding labels to one-hot form.

    Args:
      labels: (LongTensor) class labels, sized [N,].
      num_classes: (int) number of classes.

    Returns:
      (tensor) encoded labels, sized [N, #classes].
    """
    y = torch.eye(num_classes) 
    return y[labels] 
# one_hot_embedding(1, 10)
def part_init(istrain=True):
    r_list = []
    b_list = []
    vein_list = []
    prints_list = []
    labels = []
    
        # split all data into train, test data
    train_ratio = 1
    train_num = int(500 * train_ratio)
    print("split train users:",train_num)
    if istrain:
        for i in tqdm.tqdm(range(train_num)):
            for j in range(8):
                r_img = np.array(Image.open(os.path.join(r_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                r_normed = (r_img - r_img.min()) / (r_img.max()-r_img.min())
                
                g_img = np.array(Image.open(os.path.join(g_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                g_normed = (g_img - g_img.min()) / (g_img.max()-g_img.min())

                b_img = np.array(Image.open(os.path.join(b_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                b_normed = (b_img - b_img.min()) / (b_img.max()-b_img.min())

                n_img = np.array(Image.open(os.path.join(n_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                r_normed = (n_img - n_img.min()) / (n_img.max()-n_img.min())
                
                rb = r_normed - b_normed * 0.5
                rb =  (rb * 128+128).astype(np.uint8)

                imgprint = np.dstack((r_img,g_img,b_img))
                imgvein = np.dstack((rb, n_img))
                
                vein_list.append(imgvein)
                prints_list.append(imgprint)
                labels.append(one_hot_embedding(i, train_num))
#                 labels.append(i)
    else:
        for i in tqdm.tqdm(range(train_num)):
            for j in range(8,12):
                r_img = np.array(Image.open(os.path.join(r_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                r_normed = (r_img - r_img.min()) / (r_img.max()-r_img.min())
                
                g_img = np.array(Image.open(os.path.join(g_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                g_normed = (g_img - g_img.min()) / (g_img.max()-g_img.min())

                b_img = np.array(Image.open(os.path.join(b_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                b_normed = (b_img - b_img.min()) / (b_img.max()-b_img.min())

                n_img = np.array(Image.open(os.path.join(n_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                r_normed = (n_img - n_img.min()) / (n_img.max()-n_img.min())
                
                rb = r_normed - b_normed * 0.5
                rb =  (rb * 128+128).astype(np.uint8)
                imgprint = np.dstack((r_img,g_img,b_img))
                imgvein = np.dstack((rb, n_img))
                
                vein_list.append(imgvein)
                prints_list.append(imgprint)
                labels.append(one_hot_embedding(i, train_num))
#                 labels.append(i)



    # return np.array(r_list), np.array(b_list), np.array(n_list), np.array(labels),np.array(r_list_test), np.array(b_list_test), np.array(n_list_test), np.array(labels_test)
    return  vein_list,prints_list, labels

# r_list, b_list, n_list, labels,r_list_test, b_list_test, n_list_test, labels_test = part_init()
class load_data(Dataset):
    """Loads the Data."""
    def __init__(self, training=True):

        self.training = training
#         r_list, b_list, n_list, labels,r_list_test, b_list_test, n_list_test, labels_test = part_init()
        self.transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.ColorJitter(),
        transforms.RandomRotation(degrees=15),
        transforms.RandomPerspective(),
        transforms.RandomAffine(30),
        transforms.ToTensor(),
#         transforms.Resize((224, 224)),# if resnet
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225]),
    ])
        self.transform_test = transforms.Compose([
        transforms.ToPILImage(),
#         transforms.Resize((224, 224)),# if resnet
        transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225]),
    ])
        if self.training:
            print('\n...... Train files loading\n')
            self.vein_list,self.prints_list, self.labels= part_init(istrain=True)
            print('\nTrain files loaded ......\n')
        else:
            print('\n...... Test files loading\n')
            self.vein_list,self.prints_list, self.labels = part_init(istrain=False)
            print('\nTest files loaded ......\n')

    def __len__(self):
        return len(self.vein_list)

         
    def __getitem__(self, idx):

        if self.training:
            prints_img = self.transform(self.prints_list[idx])
            vein_img = self.transform(self.vein_list[idx])
        else:
            prints_img = self.transform_test(self.prints_list[idx])
            vein_img = self.transform_test(self.vein_list[idx])
        
        label = self.labels[idx]
        
        n_img = np.dstack((prints_img[0,:,:],prints_img[1,:,:],prints_img[2,:,:],vein_img[0,:,:],vein_img[1,:,:]))
        
        return n_img,label

# %%
def get_config():
    config = {
        "lambda": 0.1,
        "optimizer": {"type": optim.RMSprop, "optim_params": {"lr": 1e-5, "weight_decay": 10 ** -5}},
        "info": "[CSQ]",
        "resize_size": 256,
        "crop_size": 224,
        "batch_size": 64,
        # "net": AlexNet,
        "net": "w",
        "dataset": "palmprint",
        "n_class":500,
        # "dataset": "imagenet",
        # "dataset": "coco",
        # "dataset": "nuswide_21",
        # "dataset": "nuswide_21_m",
        "epoch": 500,
        "test_map": 10,
        # "device":torch.device("cpu"),
        "device": torch.device("cuda:0"),
        "bit_list": [1024],
    }
#     config = config_dataset(config)
    return config



config = get_config()
print(config)
bit = 1024

device = torch.device("cuda:0")
# Out:
# {'lambda': 0.1, 'optimizer': {'type': <class 'torch.optim.rmsprop.RMSprop'>, 'optim_params': {'lr': 1e-05, 'weight_decay': 1e-05}}, 'info': '[CSQ]', 'resize_size': 256, 'crop_size': 224, 'batch_size': 64, 'net': 'w', 'dataset': 'palmprint', 'n_class': 500, 'epoch': 500, 'test_map': 10, 'device': device(type='cuda', index=0), 'bit_list': [1024]}

# %%
# train_loader, test_loader, dataset_loader, num_train, num_test, num_dataset = get_data(config)
batch_size = 300
train_loader = DataLoader(load_data(training=True), batch_size=batch_size, shuffle=True, num_workers=8, pin_memory=True,prefetch_factor=8)  # ,prefetch_factor=2
test_loader = DataLoader(load_data(training=False), batch_size=64, shuffle=False)  # ,prefetch_factor=2
# Out:
# ...... Train files loading
#
# split train users: 500
# 100%|██████████| 500/500 [01:23<00:00,  6.02it/s]
# Train files loaded ......
#
#
# ...... Test files loading
#
# split train users: 500
# 100%|██████████| 500/500 [00:43<00:00, 11.53it/s]
# Test files loaded ......

# %%
# batch_size = 32
dataset_loader = train_loader
num_train = 4000
num_test = 2000
num_dataset = 6000

# %%
# !pip install scipy

# %%
from tools import *
# from network import *

import os
import torch
import torch.optim as optim
import time
import numpy as np
from scipy.linalg import hadamard  # direct import  hadamrd matrix from scipy
import random

torch.multiprocessing.set_sharing_strategy('file_system')


class CSQLoss(torch.nn.Module):
    def __init__(self, config, bit):
        super(CSQLoss, self).__init__()
        self.is_single_label = config["dataset"] not in {"nuswide_21", "nuswide_21_m", "coco"}
        self.hash_targets = self.get_hash_targets(config["n_class"], bit).to(config["device"])
        self.multi_label_random_center = torch.randint(2, (bit,)).float().to(config["device"])
        self.criterion = torch.nn.BCELoss().to(config["device"])

    def forward(self, u, y, ind, config):
        u = u.tanh()
        hash_center = self.label2center(y)
        center_loss = self.criterion(0.5 * (u + 1), 0.5 * (hash_center + 1))

        Q_loss = (u.abs() - 1).pow(2).mean()
        return center_loss + config["lambda"] * Q_loss

    def label2center(self, y):
        if self.is_single_label:
            hash_center = self.hash_targets[y.argmax(axis=1)]
        else:
            # to get sign no need to use mean, use sum here
            center_sum = y @ self.hash_targets
            random_center = self.multi_label_random_center.repeat(center_sum.shape[0], 1)
            center_sum[center_sum == 0] = random_center[center_sum == 0]
            hash_center = 2 * (center_sum > 0).float() - 1
        return hash_center

    # use algorithm 1 to generate hash centers
    def get_hash_targets(self, n_class, bit):
        H_K = hadamard(bit)
        H_2K = np.concatenate((H_K, -H_K), 0)
        hash_targets = torch.from_numpy(H_2K[:n_class]).float()

        if H_2K.shape[0] < n_class:
            hash_targets.resize_(n_class, bit)
            for k in range(20):
                for index in range(H_2K.shape[0], n_class):
                    ones = torch.ones(bit)
                    # Bernouli distribution
                    sa = random.sample(list(range(bit)), bit // 2)
                    ones[sa] = -1
                    hash_targets[index] = ones
                # to find average/min  pairwise distance
                c = []
                for i in range(n_class):
                    for j in range(n_class):
                        if i < j:
                            TF = sum(hash_targets[i] != hash_targets[j])
                            c.append(TF)
                c = np.array(c)

                # choose min(c) in the range of K/4 to K/3
                # see in https://github.com/yuanli2333/Hadamard-Matrix-for-hashing/issues/1
                # but it is hard when bit is  small
                if c.min() > bit / 4 and c.mean() >= bit / 2:
                    print(c.min(), c.mean())
                    break
        return hash_targets

# %%
# # Calculate the total parameters of the model
# print('Model size: {:0.2f} million float parameters'.format(get_parameters_size(model)/1e6))
# args.pretrained = 'model_best.pth.tar'
# if os.path.isfile(args.pretrained):
#     print("=> loading checkpoint '{}'".format(args.pretrained))
#     checkpoint = torch.load(args.pretrained)
#     model.load_state_dict(checkpoint['state_dict'])
# else:
#     print("=> no checkpoint found at '{}'".format(args.pretrained))

# %%
config["num_train"] = num_train
model = model.to(device)

optimizer = config["optimizer"]["type"](model.parameters(), **(config["optimizer"]["optim_params"]))

criterion = CSQLoss(config, bit)

# optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=args.momentum, weight_decay=3e-05)
scheduler = StepLR(optimizer, step_size=100, gamma=0.9)

# %%
# device

# %%
import numpy as np

def normalized(a, axis=-1, order=2):
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2==0] = 1
    return a / np.expand_dims(l2, axis)

A = np.random.randn(1,2)*10
# print(A)
# print(normalized(A,0))
print(normalized(A,1))# ok verified


def test(net,test_loader):
    test_loss = AverageMeter()
    acc = AverageMeter()
    FEATS = []
    GT = []
    net.eval()
    features = {}
    with torch.no_grad():
        for batch_idx, img in enumerate(test_loader):
            rbn = img[0].permute(0, 3, 1, 2).to(device, dtype=torch.float)
            label = img[1].to(device)

            output = net(rbn)
            FEATS.append(output.cpu().numpy())
#             FEATS.append(features['feats'].cpu().numpy())
            GT.append(img[1].numpy())

    GCNFEATS = np.concatenate(FEATS)
    GT = np.concatenate(GT)
    GCNFEATS = normalized(GCNFEATS,1)
    print('- feats shape:', GCNFEATS.shape)
    print('- GT shape:', GT.shape)
    from numpy import dot
    from numpy.linalg import norm

    def cossim(a,b):
        return dot(a, b)/(norm(a)*norm(b))

    pred_scores = []
    gt_label = []

    for i in range(2000):
        for j in range(i+1,2000):
            # pred_scores.append(final[i,j].detach().cpu().numpy())
            a = cossim(GCNFEATS[i,:],GCNFEATS[j,:])
            pred_scores.append(a)
            gt_label.append(i//4 == j//4)

    pred_scores = np.array(pred_scores)
    gt_label = np.array(gt_label)

    Gen = pred_scores[gt_label]
    Imp = pred_scores[gt_label==False]
    Imp = Imp[np.random.permutation(len(Imp))[:len(Gen)]]


#     import seaborn as sns
#     sns.distplot(Gen,  kde=False, label='Gen')
#     # df =gapminder[gapminder.continent == 'Americas']
#     sns.distplot(Imp,  kde=False,label='Imp')
#     # Plot formatting
#     plt.legend(prop={'size': 12})
#     plt.title('Life Expectancy of Two Continents')
#     plt.xlabel('Life Exp (years)')
#     plt.ylabel('Density')

    from pyeer.eer_info import get_eer_stats
    from pyeer.report import generate_eer_report, export_error_rates
    from pyeer.plot import plot_eer_stats


    # Calculating stats for classifier A
    stats_a = get_eer_stats(Gen, Imp)
    print(stats_a.eer)

    return stats_a.eer

##### INSPECT FEATURES
# Out:
# [[ 0.72978753 -0.68367402]]

# %%
Best_eer = 1.0

config["epoch"] = 2000
for epoch in range(500,config["epoch"]):

    current_time = time.strftime('%H:%M:%S', time.localtime(time.time()))

    print("%s[%2d/%2d][%s] bit:%d, dataset:%s, training...." % (
        config["info"], epoch + 1, config["epoch"], current_time, bit, config["dataset"]), end="")

    model.train()

    train_loss = 0
    for batch_idx, img in enumerate(train_loader):
        image = img[0].permute(0, 3, 1, 2).to(device, dtype=torch.float)
        label = img[1].to(device)

        optimizer.zero_grad()
        u = model(image)

        loss = criterion(u, label.float(), 0, config)
        train_loss += loss.item()

        loss.backward()
        optimizer.step()

    train_loss = train_loss / len(train_loader)
    if epoch % 50 ==0:
        eer = test(model,test_loader)
        if eer < Best_eer:
            Best_eer = eer
            save_checkpoint({
                'epoch': epoch + 1,
                'state_dict': model.state_dict(),
                'best_prec1': Best_eer,
                'optimizer' : optimizer.state_dict(),
            }, True, filename='checkpointGCN2wayHashingsimple.pth.tar', remark='GCN2wayHashingsimple')
        print("%s epoch:%d, bit:%d, dataset:%s,eer:%.5f, Best eer: %.5f" % (
            config["info"], epoch + 1, bit, config["dataset"], eer, Best_eer))
    print("\b\b\b\b\b\b\b loss:%.5f" % (train_loss))##loss:0.625
    scheduler.step()

#     if (epoch + 1) % config["test_map"] == 0:
#         # print("calculating test binary code......")
#         tst_binary, tst_label = compute_result(test_loader, net, device=device)

#         # print("calculating dataset binary code.......")\
#         trn_binary, trn_label = compute_result(dataset_loader, net, device=device)

#         # print("calculating map.......")
#         mAP = CalcTopMap(trn_binary.numpy(), tst_binary.numpy(), trn_label.numpy(), tst_label.numpy(),
#                          config["topK"])

#         if mAP > Best_mAP:
#             Best_mAP = mAP

#             if "save_path" in config:
#                 if not os.path.exists(config["save_path"]):
#                     os.makedirs(config["save_path"])
#                 print("save in ", config["save_path"])
#                 np.save(os.path.join(config["save_path"], config["dataset"] + str(mAP) + "-" + "trn_binary.npy"),
#                         trn_binary.numpy())
#                 torch.save(net.state_dict(),
#                            os.path.join(config["save_path"], config["dataset"] + "-" + str(mAP) + "-model.pt"))
#         print("%s epoch:%d, bit:%d, dataset:%s, MAP:%.3f, Best MAP: %.3f" % (
#             config["info"], epoch + 1, bit, config["dataset"], mAP, Best_mAP))
#         print(config)
# Out:
# [CSQ][501/2000][13:01:37] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.02266666666666667
# [CSQ] epoch:501, bit:1024, dataset:palmprint,eer:0.02267, Best eer: 0.02267
#  loss:1.34724
# [CSQ][502/2000][13:03:23] bit:1024, dataset:palmprint, training... loss:1.13188
# [CSQ][503/2000][13:03:36] bit:1024, dataset:palmprint, training... loss:1.08966
# [CSQ][504/2000][13:03:49] bit:1024, dataset:palmprint, training... loss:1.05679
# [CSQ][505/2000][13:04:04] bit:1024, dataset:palmprint, training... loss:1.03082
# [CSQ][506/2000][13:04:16] bit:1024, dataset:palmprint, training... loss:1.00820
# [CSQ][507/2000][13:04:30] bit:1024, dataset:palmprint, training... loss:0.98915
# [CSQ][508/2000][13:04:43] bit:1024, dataset:palmprint, training... loss:0.97001
# [CSQ][509/2000][13:04:56] bit:1024, dataset:palmprint, training... loss:0.95684
# [CSQ][510/2000][13:05:11] bit:1024, dataset:palmprint, training... loss:0.94163
# [CSQ][511/2000][13:05:24] bit:1024, dataset:palmprint, training... loss:0.92842
# [CSQ][512/2000][13:05:38] bit:1024, dataset:palmprint, training... loss:0.91547
# [CSQ][513/2000][13:05:50] bit:1024, dataset:palmprint, training... loss:0.90493
# [CSQ][514/2000][13:06:04] bit:1024, dataset:palmprint, training... loss:0.89545
# [CSQ][515/2000][13:06:20] bit:1024, dataset:palmprint, training... loss:0.88584
# [CSQ][516/2000][13:06:32] bit:1024, dataset:palmprint, training... loss:0.87796
# [CSQ][517/2000][13:06:44] bit:1024, dataset:palmprint, training... loss:0.86964
# [CSQ][518/2000][13:06:56] bit:1024, dataset:palmprint, training... loss:0.86361
# [CSQ][519/2000][13:07:08] bit:1024, dataset:palmprint, training... loss:0.85827
# [CSQ][520/2000][13:07:21] bit:1024, dataset:palmprint, training... loss:0.85119
# [CSQ][521/2000][13:07:34] bit:1024, dataset:palmprint, training... loss:0.84591
# [CSQ][522/2000][13:07:49] bit:1024, dataset:palmprint, training... loss:0.84167
# [CSQ][523/2000][13:08:01] bit:1024, dataset:palmprint, training... loss:0.83591
# [CSQ][524/2000][13:08:14] bit:1024, dataset:palmprint, training... loss:0.83224
# [CSQ][525/2000][13:08:29] bit:1024, dataset:palmprint, training... loss:0.82889
# [CSQ][526/2000][13:08:41] bit:1024, dataset:palmprint, training... loss:0.82501
# [CSQ][527/2000][13:08:56] bit:1024, dataset:palmprint, training... loss:0.82127
# [CSQ][528/2000][13:09:09] bit:1024, dataset:palmprint, training... loss:0.81808
# [CSQ][529/2000][13:09:23] bit:1024, dataset:palmprint, training... loss:0.81639
# [CSQ][530/2000][13:09:36] bit:1024, dataset:palmprint, training... loss:0.81393
# [CSQ][531/2000][13:09:48] bit:1024, dataset:palmprint, training... loss:0.81042
# [CSQ][532/2000][13:10:03] bit:1024, dataset:palmprint, training... loss:0.80827
# [CSQ][533/2000][13:10:15] bit:1024, dataset:palmprint, training... loss:0.80590
# [CSQ][534/2000][13:10:29] bit:1024, dataset:palmprint, training... loss:0.80457
# [CSQ][535/2000][13:10:42] bit:1024, dataset:palmprint, training... loss:0.80313
# [CSQ][536/2000][13:10:55] bit:1024, dataset:palmprint, training... loss:0.80176
# [CSQ][537/2000][13:11:10] bit:1024, dataset:palmprint, training... loss:0.80129
# [CSQ][538/2000][13:11:22] bit:1024, dataset:palmprint, training... loss:0.79757
# [CSQ][539/2000][13:11:36] bit:1024, dataset:palmprint, training... loss:0.79636
# [CSQ][540/2000][13:11:50] bit:1024, dataset:palmprint, training... loss:0.79531
# [CSQ][541/2000][13:12:02] bit:1024, dataset:palmprint, training... loss:0.79339
# [CSQ][542/2000][13:12:17] bit:1024, dataset:palmprint, training... loss:0.79256
# [CSQ][543/2000][13:12:29] bit:1024, dataset:palmprint, training... loss:0.79174
# [CSQ][544/2000][13:12:42] bit:1024, dataset:palmprint, training... loss:0.78932
# [CSQ][545/2000][13:12:57] bit:1024, dataset:palmprint, training... loss:0.78972
# [CSQ][546/2000][13:13:10] bit:1024, dataset:palmprint, training... loss:0.78963
# [CSQ][547/2000][13:13:25] bit:1024, dataset:palmprint, training... loss:0.78743
# [CSQ][548/2000][13:13:37] bit:1024, dataset:palmprint, training... loss:0.78642
# [CSQ][549/2000][13:13:50] bit:1024, dataset:palmprint, training... loss:0.78585
# [CSQ][550/2000][13:14:05] bit:1024, dataset:palmprint, training... loss:0.78565
# [CSQ][551/2000][13:14:17] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.017
# [CSQ] epoch:551, bit:1024, dataset:palmprint,eer:0.01700, Best eer: 0.01700
#  loss:0.78376
# [CSQ][552/2000][13:16:06] bit:1024, dataset:palmprint, training... loss:0.78329
# [CSQ][553/2000][13:16:18] bit:1024, dataset:palmprint, training... loss:0.78402
# [CSQ][554/2000][13:16:31] bit:1024, dataset:palmprint, training... loss:0.78211
# [CSQ][555/2000][13:16:45] bit:1024, dataset:palmprint, training... loss:0.78172
# [CSQ][556/2000][13:16:57] bit:1024, dataset:palmprint, training... loss:0.78103
# [CSQ][557/2000][13:17:12] bit:1024, dataset:palmprint, training... loss:0.77990
# [CSQ][558/2000][13:17:25] bit:1024, dataset:palmprint, training... loss:0.77879
# [CSQ][559/2000][13:17:37] bit:1024, dataset:palmprint, training... loss:0.77971
# [CSQ][560/2000][13:17:53] bit:1024, dataset:palmprint, training... loss:0.77745
# [CSQ][561/2000][13:18:05] bit:1024, dataset:palmprint, training... loss:0.77605
# [CSQ][562/2000][13:18:21] bit:1024, dataset:palmprint, training... loss:0.77672
# [CSQ][563/2000][13:18:33] bit:1024, dataset:palmprint, training... loss:0.77637
# [CSQ][564/2000][13:18:48] bit:1024, dataset:palmprint, training... loss:0.77578
# [CSQ][565/2000][13:19:00] bit:1024, dataset:palmprint, training... loss:0.77520
# [CSQ][566/2000][13:19:12] bit:1024, dataset:palmprint, training... loss:0.77378
# [CSQ][567/2000][13:19:26] bit:1024, dataset:palmprint, training... loss:0.77284
# [CSQ][568/2000][13:19:39] bit:1024, dataset:palmprint, training... loss:0.77417
# [CSQ][569/2000][13:19:51] bit:1024, dataset:palmprint, training... loss:0.77295
# [CSQ][570/2000][13:20:06] bit:1024, dataset:palmprint, training... loss:0.77133
# [CSQ][571/2000][13:20:19] bit:1024, dataset:palmprint, training... loss:0.77129
# [CSQ][572/2000][13:20:33] bit:1024, dataset:palmprint, training... loss:0.77084
# [CSQ][573/2000][13:20:46] bit:1024, dataset:palmprint, training... loss:0.76977
# [CSQ][574/2000][13:20:58] bit:1024, dataset:palmprint, training... loss:0.77074
# [CSQ][575/2000][13:21:13] bit:1024, dataset:palmprint, training... loss:0.76950
# [CSQ][576/2000][13:21:25] bit:1024, dataset:palmprint, training... loss:0.76911
# [CSQ][577/2000][13:21:38] bit:1024, dataset:palmprint, training... loss:0.76725
# [CSQ][578/2000][13:21:53] bit:1024, dataset:palmprint, training... loss:0.77008
# [CSQ][579/2000][13:22:05] bit:1024, dataset:palmprint, training... loss:0.76622
# [CSQ][580/2000][13:22:19] bit:1024, dataset:palmprint, training... loss:0.76638
# [CSQ][581/2000][13:22:32] bit:1024, dataset:palmprint, training... loss:0.76610
# [CSQ][582/2000][13:22:45] bit:1024, dataset:palmprint, training... loss:0.76506
# [CSQ][583/2000][13:23:00] bit:1024, dataset:palmprint, training... loss:0.76589
# [CSQ][584/2000][13:23:12] bit:1024, dataset:palmprint, training... loss:0.76528
# [CSQ][585/2000][13:23:26] bit:1024, dataset:palmprint, training... loss:0.76308
# [CSQ][586/2000][13:23:39] bit:1024, dataset:palmprint, training... loss:0.76343
# [CSQ][587/2000][13:23:52] bit:1024, dataset:palmprint, training... loss:0.76430
# [CSQ][588/2000][13:24:06] bit:1024, dataset:palmprint, training... loss:0.76305
# [CSQ][589/2000][13:24:21] bit:1024, dataset:palmprint, training... loss:0.76203
# [CSQ][590/2000][13:24:33] bit:1024, dataset:palmprint, training... loss:0.76177
# [CSQ][591/2000][13:24:46] bit:1024, dataset:palmprint, training... loss:0.76093
# [CSQ][592/2000][13:24:57] bit:1024, dataset:palmprint, training... loss:0.76116
# [CSQ][593/2000][13:25:09] bit:1024, dataset:palmprint, training... loss:0.76060
# [CSQ][594/2000][13:25:22] bit:1024, dataset:palmprint, training... loss:0.76028
# [CSQ][595/2000][13:25:34] bit:1024, dataset:palmprint, training... loss:0.76008
# [CSQ][596/2000][13:25:47] bit:1024, dataset:palmprint, training... loss:0.75825
# [CSQ][597/2000][13:26:01] bit:1024, dataset:palmprint, training... loss:0.75916
# [CSQ][598/2000][13:26:13] bit:1024, dataset:palmprint, training... loss:0.75910
# [CSQ][599/2000][13:26:28] bit:1024, dataset:palmprint, training... loss:0.75708
# [CSQ][600/2000][13:26:40] bit:1024, dataset:palmprint, training... loss:0.75706
# [CSQ][601/2000][13:26:52] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.012
# [CSQ] epoch:601, bit:1024, dataset:palmprint,eer:0.01200, Best eer: 0.01200
#  loss:0.75181
# [CSQ][602/2000][13:28:40] bit:1024, dataset:palmprint, training... loss:0.75076
# [CSQ][603/2000][13:28:53] bit:1024, dataset:palmprint, training... loss:0.75177
# [CSQ][604/2000][13:29:08] bit:1024, dataset:palmprint, training... loss:0.75175
# [CSQ][605/2000][13:29:21] bit:1024, dataset:palmprint, training... loss:0.75143
# [CSQ][606/2000][13:29:34] bit:1024, dataset:palmprint, training... loss:0.75156
# [CSQ][607/2000][13:29:47] bit:1024, dataset:palmprint, training... loss:0.75200
# [CSQ][608/2000][13:30:01] bit:1024, dataset:palmprint, training... loss:0.75187
# [CSQ][609/2000][13:30:15] bit:1024, dataset:palmprint, training... loss:0.74917
# [CSQ][610/2000][13:30:28] bit:1024, dataset:palmprint, training... loss:0.75028
# [CSQ][611/2000][13:30:43] bit:1024, dataset:palmprint, training... loss:0.75028
# [CSQ][612/2000][13:30:56] bit:1024, dataset:palmprint, training... loss:0.74934
# [CSQ][613/2000][13:31:09] bit:1024, dataset:palmprint, training... loss:0.75072
# [CSQ][614/2000][13:31:24] bit:1024, dataset:palmprint, training... loss:0.74997
# [CSQ][615/2000][13:31:36] bit:1024, dataset:palmprint, training... loss:0.74899
# [CSQ][616/2000][13:31:50] bit:1024, dataset:palmprint, training... loss:0.74812
# [CSQ][617/2000][13:32:03] bit:1024, dataset:palmprint, training... loss:0.74788
# [CSQ][618/2000][13:32:15] bit:1024, dataset:palmprint, training... loss:0.74703
# [CSQ][619/2000][13:32:30] bit:1024, dataset:palmprint, training... loss:0.74647
# [CSQ][620/2000][13:32:43] bit:1024, dataset:palmprint, training... loss:0.74576
# [CSQ][621/2000][13:32:56] bit:1024, dataset:palmprint, training... loss:0.74525
# [CSQ][622/2000][13:33:09] bit:1024, dataset:palmprint, training... loss:0.74640
# [CSQ][623/2000][13:33:25] bit:1024, dataset:palmprint, training... loss:0.74438
# [CSQ][624/2000][13:33:36] bit:1024, dataset:palmprint, training... loss:0.74413
# [CSQ][625/2000][13:33:48] bit:1024, dataset:palmprint, training... loss:0.74442
# [CSQ][626/2000][13:34:00] bit:1024, dataset:palmprint, training... loss:0.74425
# [CSQ][627/2000][13:34:12] bit:1024, dataset:palmprint, training... loss:0.74320
# [CSQ][628/2000][13:34:24] bit:1024, dataset:palmprint, training... loss:0.74269
# [CSQ][629/2000][13:34:37] bit:1024, dataset:palmprint, training... loss:0.74199
# [CSQ][630/2000][13:34:50] bit:1024, dataset:palmprint, training... loss:0.74277
# [CSQ][631/2000][13:35:03] bit:1024, dataset:palmprint, training... loss:0.74050
# [CSQ][632/2000][13:35:16] bit:1024, dataset:palmprint, training... loss:0.74088
# [CSQ][633/2000][13:35:30] bit:1024, dataset:palmprint, training... loss:0.74089
# [CSQ][634/2000][13:35:43] bit:1024, dataset:palmprint, training... loss:0.74042
# [CSQ][635/2000][13:35:57] bit:1024, dataset:palmprint, training... loss:0.73959
# [CSQ][636/2000][13:36:10] bit:1024, dataset:palmprint, training... loss:0.73994
# [CSQ][637/2000][13:36:22] bit:1024, dataset:palmprint, training... loss:0.73857
# [CSQ][638/2000][13:36:37] bit:1024, dataset:palmprint, training... loss:0.73828
# [CSQ][639/2000][13:36:49] bit:1024, dataset:palmprint, training... loss:0.73827
# [CSQ][640/2000][13:37:02] bit:1024, dataset:palmprint, training... loss:0.73779
# [CSQ][641/2000][13:37:17] bit:1024, dataset:palmprint, training... loss:0.73816
# [CSQ][642/2000][13:37:29] bit:1024, dataset:palmprint, training... loss:0.73733
# [CSQ][643/2000][13:37:43] bit:1024, dataset:palmprint, training... loss:0.73718
# [CSQ][644/2000][13:37:56] bit:1024, dataset:palmprint, training... loss:0.73621
# [CSQ][645/2000][13:38:08] bit:1024, dataset:palmprint, training... loss:0.73667
# [CSQ][646/2000][13:38:23] bit:1024, dataset:palmprint, training... loss:0.73567
# [CSQ][647/2000][13:38:36] bit:1024, dataset:palmprint, training... loss:0.73442
# [CSQ][648/2000][13:38:49] bit:1024, dataset:palmprint, training... loss:0.73444
# [CSQ][649/2000][13:39:02] bit:1024, dataset:palmprint, training... loss:0.73440
# [CSQ][650/2000][13:39:14] bit:1024, dataset:palmprint, training... loss:0.73345
# [CSQ][651/2000][13:39:29] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.009
# [CSQ] epoch:651, bit:1024, dataset:palmprint,eer:0.00900, Best eer: 0.00900
#  loss:0.73412
# [CSQ][652/2000][13:41:42] bit:1024, dataset:palmprint, training... loss:0.73311
# [CSQ][653/2000][13:41:56] bit:1024, dataset:palmprint, training... loss:0.73223
# [CSQ][654/2000][13:42:09] bit:1024, dataset:palmprint, training... loss:0.73141
# [CSQ][655/2000][13:42:26] bit:1024, dataset:palmprint, training... loss:0.73142
# [CSQ][656/2000][13:42:38] bit:1024, dataset:palmprint, training... loss:0.73167
# [CSQ][657/2000][13:42:50] bit:1024, dataset:palmprint, training... loss:0.73097
# [CSQ][658/2000][13:43:02] bit:1024, dataset:palmprint, training... loss:0.73073
# [CSQ][659/2000][13:43:14] bit:1024, dataset:palmprint, training... loss:0.73149
# [CSQ][660/2000][13:43:29] bit:1024, dataset:palmprint, training... loss:0.72968
# [CSQ][661/2000][13:43:41] bit:1024, dataset:palmprint, training... loss:0.72876
# [CSQ][662/2000][13:43:54] bit:1024, dataset:palmprint, training... loss:0.72952
# [CSQ][663/2000][13:44:08] bit:1024, dataset:palmprint, training... loss:0.72860
# [CSQ][664/2000][13:44:21] bit:1024, dataset:palmprint, training... loss:0.72763
# [CSQ][665/2000][13:44:35] bit:1024, dataset:palmprint, training... loss:0.72795
# [CSQ][666/2000][13:44:48] bit:1024, dataset:palmprint, training... loss:0.72765
# [CSQ][667/2000][13:45:00] bit:1024, dataset:palmprint, training... loss:0.72722
# [CSQ][668/2000][13:45:14] bit:1024, dataset:palmprint, training... loss:0.72711
# [CSQ][669/2000][13:45:26] bit:1024, dataset:palmprint, training... loss:0.72581
# [CSQ][670/2000][13:45:39] bit:1024, dataset:palmprint, training... loss:0.72544
# [CSQ][671/2000][13:45:54] bit:1024, dataset:palmprint, training... loss:0.72574
# [CSQ][672/2000][13:46:06] bit:1024, dataset:palmprint, training... loss:0.72547
# [CSQ][673/2000][13:46:21] bit:1024, dataset:palmprint, training... loss:0.72354
# [CSQ][674/2000][13:46:34] bit:1024, dataset:palmprint, training... loss:0.72339
# [CSQ][675/2000][13:46:47] bit:1024, dataset:palmprint, training... loss:0.72413
# [CSQ][676/2000][13:47:01] bit:1024, dataset:palmprint, training... loss:0.72289
# [CSQ][677/2000][13:47:13] bit:1024, dataset:palmprint, training... loss:0.72291
# [CSQ][678/2000][13:47:28] bit:1024, dataset:palmprint, training... loss:0.72218
# [CSQ][679/2000][13:47:40] bit:1024, dataset:palmprint, training... loss:0.72173
# [CSQ][680/2000][13:47:55] bit:1024, dataset:palmprint, training... loss:0.72168
# [CSQ][681/2000][13:48:08] bit:1024, dataset:palmprint, training... loss:0.72176
# [CSQ][682/2000][13:48:21] bit:1024, dataset:palmprint, training... loss:0.72170
# [CSQ][683/2000][13:48:35] bit:1024, dataset:palmprint, training... loss:0.72086
# [CSQ][684/2000][13:48:48] bit:1024, dataset:palmprint, training... loss:0.72040
# [CSQ][685/2000][13:49:02] bit:1024, dataset:palmprint, training... loss:0.72055
# [CSQ][686/2000][13:49:15] bit:1024, dataset:palmprint, training... loss:0.71942
# [CSQ][687/2000][13:49:30] bit:1024, dataset:palmprint, training... loss:0.71867
# [CSQ][688/2000][13:49:43] bit:1024, dataset:palmprint, training... loss:0.71978
# [CSQ][689/2000][13:49:56] bit:1024, dataset:palmprint, training... loss:0.71841
# [CSQ][690/2000][13:50:11] bit:1024, dataset:palmprint, training... loss:0.71925
# [CSQ][691/2000][13:50:23] bit:1024, dataset:palmprint, training... loss:0.71655
# [CSQ][692/2000][13:50:37] bit:1024, dataset:palmprint, training... loss:0.71793
# [CSQ][693/2000][13:50:49] bit:1024, dataset:palmprint, training... loss:0.71809
# [CSQ][694/2000][13:51:02] bit:1024, dataset:palmprint, training... loss:0.71786
# [CSQ][695/2000][13:51:18] bit:1024, dataset:palmprint, training... loss:0.71622
# [CSQ][696/2000][13:51:32] bit:1024, dataset:palmprint, training... loss:0.71537
# [CSQ][697/2000][13:51:44] bit:1024, dataset:palmprint, training... loss:0.71517
# [CSQ][698/2000][13:51:56] bit:1024, dataset:palmprint, training... loss:0.71607
# [CSQ][699/2000][13:52:08] bit:1024, dataset:palmprint, training... loss:0.71467
# [CSQ][700/2000][13:52:20] bit:1024, dataset:palmprint, training... loss:0.71590
# [CSQ][701/2000][13:52:32] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.007333333333333333
# [CSQ] epoch:701, bit:1024, dataset:palmprint,eer:0.00733, Best eer: 0.00733
#  loss:0.71012
# [CSQ][702/2000][13:54:45] bit:1024, dataset:palmprint, training... loss:0.70874
# [CSQ][703/2000][13:54:58] bit:1024, dataset:palmprint, training... loss:0.71061
# [CSQ][704/2000][13:55:10] bit:1024, dataset:palmprint, training... loss:0.70976
# [CSQ][705/2000][13:55:25] bit:1024, dataset:palmprint, training... loss:0.70887
# [CSQ][706/2000][13:55:38] bit:1024, dataset:palmprint, training... loss:0.70948
# [CSQ][707/2000][13:55:52] bit:1024, dataset:palmprint, training... loss:0.71032
# [CSQ][708/2000][13:56:05] bit:1024, dataset:palmprint, training... loss:0.70980
# [CSQ][709/2000][13:56:18] bit:1024, dataset:palmprint, training... loss:0.70868
# [CSQ][710/2000][13:56:32] bit:1024, dataset:palmprint, training... loss:0.71021
# [CSQ][711/2000][13:56:45] bit:1024, dataset:palmprint, training... loss:0.70866
# [CSQ][712/2000][13:57:00] bit:1024, dataset:palmprint, training... loss:0.70808
# [CSQ][713/2000][13:57:13] bit:1024, dataset:palmprint, training... loss:0.70723
# [CSQ][714/2000][13:57:27] bit:1024, dataset:palmprint, training... loss:0.70820
# [CSQ][715/2000][13:57:40] bit:1024, dataset:palmprint, training... loss:0.70662
# [CSQ][716/2000][13:57:52] bit:1024, dataset:palmprint, training... loss:0.70682
# [CSQ][717/2000][13:58:07] bit:1024, dataset:palmprint, training... loss:0.70529
# [CSQ][718/2000][13:58:19] bit:1024, dataset:palmprint, training... loss:0.70653
# [CSQ][719/2000][13:58:32] bit:1024, dataset:palmprint, training... loss:0.70579
# [CSQ][720/2000][13:58:46] bit:1024, dataset:palmprint, training... loss:0.70613
# [CSQ][721/2000][13:58:58] bit:1024, dataset:palmprint, training... loss:0.70535
# [CSQ][722/2000][13:59:12] bit:1024, dataset:palmprint, training... loss:0.70518
# [CSQ][723/2000][13:59:25] bit:1024, dataset:palmprint, training... loss:0.70394
# [CSQ][724/2000][13:59:37] bit:1024, dataset:palmprint, training... loss:0.70444
# [CSQ][725/2000][13:59:52] bit:1024, dataset:palmprint, training... loss:0.70315
# [CSQ][726/2000][14:00:04] bit:1024, dataset:palmprint, training... loss:0.70443
# [CSQ][727/2000][14:00:22] bit:1024, dataset:palmprint, training... loss:0.70299
# [CSQ][728/2000][14:00:34] bit:1024, dataset:palmprint, training... loss:0.70235
# [CSQ][729/2000][14:00:46] bit:1024, dataset:palmprint, training... loss:0.70292
# [CSQ][730/2000][14:00:58] bit:1024, dataset:palmprint, training... loss:0.70263
# [CSQ][731/2000][14:01:10] bit:1024, dataset:palmprint, training... loss:0.70321
# [CSQ][732/2000][14:01:22] bit:1024, dataset:palmprint, training... loss:0.70282
# [CSQ][733/2000][14:01:34] bit:1024, dataset:palmprint, training... loss:0.70107
# [CSQ][734/2000][14:01:49] bit:1024, dataset:palmprint, training... loss:0.70291
# [CSQ][735/2000][14:02:02] bit:1024, dataset:palmprint, training... loss:0.69992
# [CSQ][736/2000][14:02:16] bit:1024, dataset:palmprint, training... loss:0.70047
# [CSQ][737/2000][14:02:29] bit:1024, dataset:palmprint, training... loss:0.69951
# [CSQ][738/2000][14:02:41] bit:1024, dataset:palmprint, training... loss:0.69954
# [CSQ][739/2000][14:02:57] bit:1024, dataset:palmprint, training... loss:0.69958
# [CSQ][740/2000][14:03:09] bit:1024, dataset:palmprint, training... loss:0.69936
# [CSQ][741/2000][14:03:24] bit:1024, dataset:palmprint, training... loss:0.69862
# [CSQ][742/2000][14:03:37] bit:1024, dataset:palmprint, training... loss:0.69837
# [CSQ][743/2000][14:03:51] bit:1024, dataset:palmprint, training... loss:0.69639
# [CSQ][744/2000][14:04:04] bit:1024, dataset:palmprint, training... loss:0.69732
# [CSQ][745/2000][14:04:16] bit:1024, dataset:palmprint, training... loss:0.69827
# [CSQ][746/2000][14:04:31] bit:1024, dataset:palmprint, training... loss:0.69761
# [CSQ][747/2000][14:04:43] bit:1024, dataset:palmprint, training... loss:0.69626
# [CSQ][748/2000][14:04:56] bit:1024, dataset:palmprint, training... loss:0.69623
# [CSQ][749/2000][14:05:09] bit:1024, dataset:palmprint, training... loss:0.69621
# [CSQ][750/2000][14:05:21] bit:1024, dataset:palmprint, training... loss:0.69584
# [CSQ][751/2000][14:05:36] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.007333333333333333
# [CSQ] epoch:751, bit:1024, dataset:palmprint,eer:0.00733, Best eer: 0.00733
#  loss:0.69547
# [CSQ][752/2000][14:06:54] bit:1024, dataset:palmprint, training... loss:0.69437
# [CSQ][753/2000][14:07:07] bit:1024, dataset:palmprint, training... loss:0.69555
# [CSQ][754/2000][14:07:21] bit:1024, dataset:palmprint, training... loss:0.69430
# [CSQ][755/2000][14:07:33] bit:1024, dataset:palmprint, training... loss:0.69509
# [CSQ][756/2000][14:07:48] bit:1024, dataset:palmprint, training... loss:0.69473
# [CSQ][757/2000][14:08:01] bit:1024, dataset:palmprint, training... loss:0.69244
# [CSQ][758/2000][14:08:14] bit:1024, dataset:palmprint, training... loss:0.69380
# [CSQ][759/2000][14:08:28] bit:1024, dataset:palmprint, training... loss:0.69265
# [CSQ][760/2000][14:08:40] bit:1024, dataset:palmprint, training... loss:0.69242
# [CSQ][761/2000][14:08:55] bit:1024, dataset:palmprint, training... loss:0.69360
# [CSQ][762/2000][14:09:08] bit:1024, dataset:palmprint, training... loss:0.68978
# [CSQ][763/2000][14:09:26] bit:1024, dataset:palmprint, training... loss:0.69223
# [CSQ][764/2000][14:09:38] bit:1024, dataset:palmprint, training... loss:0.69089
# [CSQ][765/2000][14:09:50] bit:1024, dataset:palmprint, training... loss:0.69192
# [CSQ][766/2000][14:10:02] bit:1024, dataset:palmprint, training... loss:0.69108
# [CSQ][767/2000][14:10:13] bit:1024, dataset:palmprint, training... loss:0.69094
# [CSQ][768/2000][14:10:26] bit:1024, dataset:palmprint, training... loss:0.68919
# [CSQ][769/2000][14:10:37] bit:1024, dataset:palmprint, training... loss:0.69010
# [CSQ][770/2000][14:10:50] bit:1024, dataset:palmprint, training... loss:0.68985
# [CSQ][771/2000][14:11:03] bit:1024, dataset:palmprint, training... loss:0.68924
# [CSQ][772/2000][14:11:17] bit:1024, dataset:palmprint, training... loss:0.68859
# [CSQ][773/2000][14:11:29] bit:1024, dataset:palmprint, training... loss:0.68722
# [CSQ][774/2000][14:11:44] bit:1024, dataset:palmprint, training... loss:0.68739
# [CSQ][775/2000][14:11:57] bit:1024, dataset:palmprint, training... loss:0.68778
# [CSQ][776/2000][14:12:09] bit:1024, dataset:palmprint, training... loss:0.68730
# [CSQ][777/2000][14:12:23] bit:1024, dataset:palmprint, training... loss:0.68699
# [CSQ][778/2000][14:12:36] bit:1024, dataset:palmprint, training... loss:0.68587
# [CSQ][779/2000][14:12:51] bit:1024, dataset:palmprint, training... loss:0.68530
# [CSQ][780/2000][14:13:03] bit:1024, dataset:palmprint, training... loss:0.68673
# [CSQ][781/2000][14:13:17] bit:1024, dataset:palmprint, training... loss:0.68572
# [CSQ][782/2000][14:13:29] bit:1024, dataset:palmprint, training... loss:0.68676
# [CSQ][783/2000][14:13:42] bit:1024, dataset:palmprint, training... loss:0.68687
# [CSQ][784/2000][14:13:56] bit:1024, dataset:palmprint, training... loss:0.68446
# [CSQ][785/2000][14:14:09] bit:1024, dataset:palmprint, training... loss:0.68442
# [CSQ][786/2000][14:14:23] bit:1024, dataset:palmprint, training... loss:0.68502
# [CSQ][787/2000][14:14:36] bit:1024, dataset:palmprint, training... loss:0.68539
# [CSQ][788/2000][14:14:50] bit:1024, dataset:palmprint, training... loss:0.68402
# [CSQ][789/2000][14:15:02] bit:1024, dataset:palmprint, training... loss:0.68275
# [CSQ][790/2000][14:15:15] bit:1024, dataset:palmprint, training... loss:0.68530
# [CSQ][791/2000][14:15:29] bit:1024, dataset:palmprint, training... loss:0.68171
# [CSQ][792/2000][14:15:42] bit:1024, dataset:palmprint, training... loss:0.68302
# [CSQ][793/2000][14:15:56] bit:1024, dataset:palmprint, training... loss:0.68171
# [CSQ][794/2000][14:16:08] bit:1024, dataset:palmprint, training... loss:0.67945
# [CSQ][795/2000][14:16:20] bit:1024, dataset:palmprint, training... loss:0.68080
# [CSQ][796/2000][14:16:34] bit:1024, dataset:palmprint, training... loss:0.68164
# [CSQ][797/2000][14:16:46] bit:1024, dataset:palmprint, training... loss:0.68036
# [CSQ][798/2000][14:17:01] bit:1024, dataset:palmprint, training... loss:0.68112
# [CSQ][799/2000][14:17:13] bit:1024, dataset:palmprint, training... loss:0.68042
# [CSQ][800/2000][14:17:25] bit:1024, dataset:palmprint, training... loss:0.67913
# [CSQ][801/2000][14:17:39] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.005666666666666667
# [CSQ] epoch:801, bit:1024, dataset:palmprint,eer:0.00567, Best eer: 0.00567
#  loss:0.67752
# [CSQ][802/2000][14:19:30] bit:1024, dataset:palmprint, training... loss:0.67651
# [CSQ][803/2000][14:19:43] bit:1024, dataset:palmprint, training... loss:0.67767
# [CSQ][804/2000][14:19:55] bit:1024, dataset:palmprint, training... loss:0.67615
# [CSQ][805/2000][14:20:09] bit:1024, dataset:palmprint, training... loss:0.67585
# [CSQ][806/2000][14:20:21] bit:1024, dataset:palmprint, training... loss:0.67561
# [CSQ][807/2000][14:20:33] bit:1024, dataset:palmprint, training... loss:0.67667
# [CSQ][808/2000][14:20:48] bit:1024, dataset:palmprint, training... loss:0.67676
# [CSQ][809/2000][14:21:00] bit:1024, dataset:palmprint, training... loss:0.67508
# [CSQ][810/2000][14:21:13] bit:1024, dataset:palmprint, training... loss:0.67529
# [CSQ][811/2000][14:21:28] bit:1024, dataset:palmprint, training... loss:0.67542
# [CSQ][812/2000][14:21:40] bit:1024, dataset:palmprint, training... loss:0.67395
# [CSQ][813/2000][14:21:55] bit:1024, dataset:palmprint, training... loss:0.67567
# [CSQ][814/2000][14:22:07] bit:1024, dataset:palmprint, training... loss:0.67562
# [CSQ][815/2000][14:22:19] bit:1024, dataset:palmprint, training... loss:0.67448
# [CSQ][816/2000][14:22:34] bit:1024, dataset:palmprint, training... loss:0.67478
# [CSQ][817/2000][14:22:46] bit:1024, dataset:palmprint, training... loss:0.67295
# [CSQ][818/2000][14:23:00] bit:1024, dataset:palmprint, training... loss:0.67363
# [CSQ][819/2000][14:23:12] bit:1024, dataset:palmprint, training... loss:0.67159
# [CSQ][820/2000][14:23:25] bit:1024, dataset:palmprint, training... loss:0.67241
# [CSQ][821/2000][14:23:40] bit:1024, dataset:palmprint, training... loss:0.67324
# [CSQ][822/2000][14:23:52] bit:1024, dataset:palmprint, training... loss:0.67249
# [CSQ][823/2000][14:24:06] bit:1024, dataset:palmprint, training... loss:0.66912
# [CSQ][824/2000][14:24:20] bit:1024, dataset:palmprint, training... loss:0.67161
# [CSQ][825/2000][14:24:32] bit:1024, dataset:palmprint, training... loss:0.67001
# [CSQ][826/2000][14:24:47] bit:1024, dataset:palmprint, training... loss:0.67097
# [CSQ][827/2000][14:24:59] bit:1024, dataset:palmprint, training... loss:0.67154
# [CSQ][828/2000][14:25:14] bit:1024, dataset:palmprint, training... loss:0.67031
# [CSQ][829/2000][14:25:26] bit:1024, dataset:palmprint, training... loss:0.66909
# [CSQ][830/2000][14:25:38] bit:1024, dataset:palmprint, training... loss:0.67058
# [CSQ][831/2000][14:25:53] bit:1024, dataset:palmprint, training... loss:0.66919
# [CSQ][832/2000][14:26:05] bit:1024, dataset:palmprint, training... loss:0.66884
# [CSQ][833/2000][14:26:20] bit:1024, dataset:palmprint, training... loss:0.66736
# [CSQ][834/2000][14:26:32] bit:1024, dataset:palmprint, training... loss:0.67020
# [CSQ][835/2000][14:26:45] bit:1024, dataset:palmprint, training... loss:0.66898
# [CSQ][836/2000][14:27:00] bit:1024, dataset:palmprint, training... loss:0.66779
# [CSQ][837/2000][14:27:13] bit:1024, dataset:palmprint, training... loss:0.66726
# [CSQ][838/2000][14:27:26] bit:1024, dataset:palmprint, training... loss:0.66657
# [CSQ][839/2000][14:27:43] bit:1024, dataset:palmprint, training... loss:0.66742
# [CSQ][840/2000][14:27:56] bit:1024, dataset:palmprint, training... loss:0.66512
# [CSQ][841/2000][14:28:08] bit:1024, dataset:palmprint, training... loss:0.66932
# [CSQ][842/2000][14:28:20] bit:1024, dataset:palmprint, training... loss:0.66705
# [CSQ][843/2000][14:28:32] bit:1024, dataset:palmprint, training... loss:0.66481
# [CSQ][844/2000][14:28:44] bit:1024, dataset:palmprint, training... loss:0.66616
# [CSQ][845/2000][14:28:58] bit:1024, dataset:palmprint, training... loss:0.66579
# [CSQ][846/2000][14:29:11] bit:1024, dataset:palmprint, training... loss:0.66468
# [CSQ][847/2000][14:29:23] bit:1024, dataset:palmprint, training... loss:0.66601
# [CSQ][848/2000][14:29:38] bit:1024, dataset:palmprint, training... loss:0.66489
# [CSQ][849/2000][14:29:50] bit:1024, dataset:palmprint, training... loss:0.66605
# [CSQ][850/2000][14:30:03] bit:1024, dataset:palmprint, training... loss:0.66543
# [CSQ][851/2000][14:30:19] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)

# %%
# # if epoch % 50 ==0:
# save_checkpoint({
#     'epoch': epoch + 1,
#     'state_dict': net.state_dict(),
#     'best_prec1': 0,
#     'optimizer' : optimizer.state_dict(),
# }, True)

# %%
# for _, img in tqdm.tqdm(enumerate(train_loader)):
#     print((img[0].size(), img[1].size()))
#     break
    
# for _, img in tqdm.tqdm(enumerate(test_loader)):
#     print((img[0].size(), img[1].size()))
#     break

# %%
# print(img[0].permute(0, 3, 1, 2).size())
# print(img[0].permute(0, 3, 1, 2).double().dtype )

# %%
model = model.float()

# %%
# outs = model(img[0].permute(0, 3, 1, 2).float())
# print(outs.size())

# %%
# # Calculate the total parameters of the model
# print('Model size: {:0.2f} million float parameters'.format(get_parameters_size(model)/1e6))
# args.pretrained = 'model_best_gcn2wayca.pth.tar'
# if os.path.isfile(args.pretrained):
#     print("=> loading checkpoint '{}'".format(args.pretrained))
#     checkpoint = torch.load(args.pretrained)
#     model.load_state_dict(checkpoint['state_dict'])
# else:
#     print("=> no checkpoint found at '{}'".format(args.pretrained))

# %%
test_loader = DataLoader(load_data(training=False), batch_size=batch_size, shuffle=False)  # ,prefetch_factor=2

# %%
for _, img in tqdm.tqdm(enumerate(test_loader)):
    print((img[0].size(), img[1].size()))
    break
print(img[1])

# %%
# ##### HELPER FUNCTION FOR FEATURE EXTRACTION
# # print(model)

# def get_features(name):
#     def hook(model, input, output):
#         features[name] = output.detach()
#     return hook
# ##### REGISTER HOOK
# model.model_print[16].register_forward_hook(get_features('feats'))
# # model.fc1.register_forward_hook(get_features('feats'))

# %%
def test(net,test_loader):
    test_loss = AverageMeter()
    acc = AverageMeter()
    FEATS = []
    GT = []
    features = {}
    with torch.no_grad():
        for batch_idx, img in enumerate(test_loader):
            rbn = img[0].permute(0, 3, 1, 2).to(device, dtype=torch.float)
            label = img[1].to(device)

            output = net(rbn)
            FEATS.append(output.cpu().numpy())
#             FEATS.append(features['feats'].cpu().numpy())
            GT.append(img[1].numpy())

    GCNFEATS = np.concatenate(FEATS)
    GT = np.concatenate(GT)
    print('- feats shape:', GCNFEATS.shape)
    print('- GT shape:', GT.shape)
    from numpy import dot
    from numpy.linalg import norm

    def cossim(a,b):
        return dot(a, b)/(norm(a)*norm(b))

    pred_scores = []
    gt_label = []

    for i in tqdm.tqdm(range(3000)):
        for j in range(i+1,3000):
            # pred_scores.append(final[i,j].detach().cpu().numpy())
            a = cossim(GCNFEATS[i,:],GCNFEATS[j,:])
            pred_scores.append(a)
            gt_label.append(i//6 == j//6)

    pred_scores = np.array(pred_scores)
    gt_label = np.array(gt_label)

    Gen = pred_scores[gt_label]
    Imp = pred_scores[gt_label==False]
    Imp = Imp[np.random.permutation(len(Imp))[:len(Gen)]]


#     import seaborn as sns
#     sns.distplot(Gen,  kde=False, label='Gen')
#     # df =gapminder[gapminder.continent == 'Americas']
#     sns.distplot(Imp,  kde=False,label='Imp')
#     # Plot formatting
#     plt.legend(prop={'size': 12})
#     plt.title('Life Expectancy of Two Continents')
#     plt.xlabel('Life Exp (years)')
#     plt.ylabel('Density')

    from pyeer.eer_info import get_eer_stats
    from pyeer.report import generate_eer_report, export_error_rates
    from pyeer.plot import plot_eer_stats


    # Calculating stats for classifier A
    stats_a = get_eer_stats(Gen, Imp)
    print(stats_a.eer)

    return stats_a.eer

test(net,test_loader)
##### INSPECT FEATURES

# %%
# np.save('FEATS_gcn2wayca.npy', GCNFEATS)

# %%
# FEATSRES18 = np.load('FEATS_res18.npy')
# print(FEATSRES18.shape)
# FEATSRES18 = np.squeeze(FEATSRES18);
# print(FEATSRES18.shape)
# # # NewFEATS = np.dstack((FEATS,FEATSRES18))
# # FEATS = np.concatenate((FEATS,FEATSRES18), axis=1)
# # print(NewFEATS.shape)

# %%
from numpy import dot
from numpy.linalg import norm

def cossim(a,b):
    return dot(a, b)/(norm(a)*norm(b))

pred_scores = []
gt_label = []

for i in tqdm.tqdm(range(3000)):
    for j in range(i+1,3000):
        # pred_scores.append(final[i,j].detach().cpu().numpy())
        a = cossim(GCNFEATS[i,:],GCNFEATS[j,:])
#         b = cossim(FEATSRES18[i,:],FEATSRES18[j,:])
#         pred_scores.append((1.8*a+0.2*b)/2)
        pred_scores.append(a)
#         pred_scores.append(b)
        gt_label.append(i//6 == j//6)
        

# for i in tqdm.tqdm(range(600)):
#         # pred_scores.append(final[i,j].detach().cpu().numpy())
#         pred_scores.append(cossim(FEATS[i,:],FEATS[]))
#         # gt_label.append(i//12 == j//12)
pred_scores = np.array(pred_scores)
gt_label = np.array(gt_label)

# %%
Gen = pred_scores[gt_label]
Imp = pred_scores[gt_label==False]
Imp = Imp[np.random.permutation(len(Imp))[:len(Gen)]]


import seaborn as sns
sns.distplot(Gen,  kde=False, label='Gen')
# df =gapminder[gapminder.continent == 'Americas']
sns.distplot(Imp,  kde=False,label='Imp')
# Plot formatting
plt.legend(prop={'size': 12})
plt.title('Life Expectancy of Two Continents')
plt.xlabel('Life Exp (years)')
plt.ylabel('Density')

from pyeer.eer_info import get_eer_stats
from pyeer.report import generate_eer_report, export_error_rates
from pyeer.plot import plot_eer_stats


# Calculating stats for classifier A
stats_a = get_eer_stats(Gen, Imp)
print(stats_a.eer)

# %%
import numpy as np
import sklearn.metrics

"""
Python compute equal error rate (eer)
ONLY tested on binary classification

:param label: ground-truth label, should be a 1-d list or np.array, each element represents the ground-truth label of one sample
:param pred: model prediction, should be a 1-d list or np.array, each element represents the model prediction of one sample
:param positive_label: the class that is viewed as positive class when computing EER
:return: equal error rate (EER)
"""
def compute_eer(label, pred, positive_label=1):
    # all fpr, tpr, fnr, fnr, threshold are lists (in the format of np.array)
    fpr, tpr, threshold = sklearn.metrics.roc_curve(label, pred)#, positive_label
    fnr = 1 - tpr

    # the threshold of fnr == fpr
    eer_threshold = threshold[np.nanargmin(np.absolute((fnr - fpr)))]

    # theoretically eer from fpr and eer from fnr should be identical but they can be slightly differ in reality
    eer_1 = fpr[np.nanargmin(np.absolute((fnr - fpr)))]
    eer_2 = fnr[np.nanargmin(np.absolute((fnr - fpr)))]

    # return the mean of eer from fpr and from fnr
    eer = (eer_1 + eer_2) / 2
    return eer

eer = compute_eer(gt_label, pred_scores)
print('The equal error rate is {:.3f}'.format(eer))

# %%
del Gen 
del Imp
del pred_scores
del gt_label
del GCNFEATS
del GT
del test_loader
