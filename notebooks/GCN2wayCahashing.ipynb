# %%
from __future__ import division
import os
import time
import argparse
import torch
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import torch.nn.functional as F
from utils import accuracy, AverageMeter, save_checkpoint, visualize_graph, get_parameters_size
from torch.utils.tensorboard import SummaryWriter
from net_factory import get_network_fn


# dataset
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.nn import DataParallel
import tqdm
import numpy as np
# del test_loader
import tqdm
# test_loader

# %%
parser = argparse.ArgumentParser(description='PyTorch GCN MNIST Training')

parser.add_argument('--epochs', default=50, type=int, metavar='N',
                    help='number of total epochs to run')
parser.add_argument('-j', '--workers', default=4, type=int, metavar='N',
                    help='number of data loading workers (default: 4)')
parser.add_argument('--start-epoch', default=0, type=int, metavar='N',
                    help='manual epoch number (useful on restarts)')
parser.add_argument('-b', '--batch-size', default=128, type=int,
                    metavar='N', help='mini-batch size (default: 64)')
parser.add_argument('--lr', '--learning-rate', default=0.01, type=float,
                    metavar='LR', help='initial learning rate')
parser.add_argument('--momentum', default=0.9, type=float, metavar='M',
                    help='momentum')
parser.add_argument('--print-freq', '-p', default=10, type=int,
                    metavar='N', help='print frequency (default: 10)')
parser.add_argument('--resume', default='', type=str, metavar='PATH',
                    help='path to latest checkpoint (default: none)')
parser.add_argument('--pretrained', default='', type=str, metavar='PATH',
                    help='path to pretrained checkpoint (default: none)')
parser.add_argument('--gpu', default=0, type=int,
                    metavar='N', help='GPU device ID (default: -1)')
parser.add_argument('--dataset_dir', default='../../MNIST', type=str, metavar='PATH',
                    help='path to dataset (default: ../MNIST)')
parser.add_argument('--comment', default='', type=str, metavar='INFO',
                    help='Extra description for tensorboard')
parser.add_argument('--model', default='gcn', type=str, metavar='NETWORK',
                    help='Network to train')

args = parser.parse_args(args=[])

use_cuda = (args.gpu >= 0) and torch.cuda.is_available()
best_prec1 = 0
writer = SummaryWriter(comment='_'+args.model+'_'+args.comment)
iteration = 0

# # from loaddataset import load_data
# from loaddataset import load_data

# batch_size = 64
# train_loader = DataLoader(load_data(training=True), batch_size=batch_size, shuffle=True)  # ,prefetch_factor=2
# test_loader = DataLoader(load_data(training=False), batch_size=batch_size, shuffle=True)  # ,prefetch_factor=2

# %%
# Load model
model = get_network_fn(name='GCN2wayCAHashing')#GCNCNN
# print(model)

# Try to visulize the model
try:
	visualize_graph(model, writer, input_size=(1, 5, 128, 128))
except:
	print('\nNetwork Visualization Failed! But the training procedure continue.')
# Out:
# /root/autodl-nas/Gabor_CNN_PyTorch/demo/net_factory.py:194: TracerWarning: Converting a tensor to a Python index might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   return x + self.pe[:, :, :x.size(2), :x.size(3)]
# /root/autodl-nas/Gabor_CNN_PyTorch/gcn/layers/GConv.py:67: TracerWarning: Converting a tensor to a Python index might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   for i in range(x.size(1)):

# %%
# Calculate the total parameters of the model
print('Model size: {:0.2f} million float parameters'.format(get_parameters_size(model)/1e6))
args.pretrained = 'model_best_gcn2waycqhashing.pth.tar'
if os.path.isfile(args.pretrained):
    print("=> loading checkpoint '{}'".format(args.pretrained))
    checkpoint = torch.load(args.pretrained,map_location=torch.device('cpu'))
    model.load_state_dict(checkpoint['state_dict'])
else:
    print("=> no checkpoint found at '{}'".format(args.pretrained))
print(checkpoint['best_prec1'])
# Out:
# Model size: 1.05 million float parameters
# => loading checkpoint 'model_best_gcn2waycqhashing.pth.tar'
# 0.018

# %%
class CSQLoss(torch.nn.Module):
    def __init__(self, config, bit):
        super(CSQLoss, self).__init__()
        self.is_single_label = config["dataset"] not in {"nuswide_21", "nuswide_21_m", "coco"}
        self.hash_targets = self.get_hash_targets(config["n_class"], bit).to(config["device"])
        self.multi_label_random_center = torch.randint(2, (bit,)).float().to(config["device"])
        self.criterion = torch.nn.BCELoss().to(config["device"])

    def forward(self, u, y, ind, config):
        u = u.tanh()
        hash_center = self.label2center(y)
        center_loss = self.criterion(0.5 * (u + 1), 0.5 * (hash_center + 1))

        Q_loss = (u.abs() - 1).pow(2).mean()
        return center_loss + config["lambda"] * Q_loss

    def label2center(self, y):
        if self.is_single_label:
            hash_center = self.hash_targets[y.argmax(axis=1)]
        else:
            # to get sign no need to use mean, use sum here
            center_sum = y @ self.hash_targets
            random_center = self.multi_label_random_center.repeat(center_sum.shape[0], 1)
            center_sum[center_sum == 0] = random_center[center_sum == 0]
            hash_center = 2 * (center_sum > 0).float() - 1
        return hash_center

    # use algorithm 1 to generate hash centers
    def get_hash_targets(self, n_class, bit):
        H_K = hadamard(bit)
        H_2K = np.concatenate((H_K, -H_K), 0)
        hash_targets = torch.from_numpy(H_2K[:n_class]).float()

        if H_2K.shape[0] < n_class:
            hash_targets.resize_(n_class, bit)
            for k in range(20):
                for index in range(H_2K.shape[0], n_class):
                    ones = torch.ones(bit)
                    # Bernouli distribution
                    sa = random.sample(list(range(bit)), bit // 2)
                    ones[sa] = -1
                    hash_targets[index] = ones
                # to find average/min  pairwise distance
                c = []
                for i in range(n_class):
                    for j in range(n_class):
                        if i < j:
                            TF = sum(hash_targets[i] != hash_targets[j])
                            c.append(TF)
                c = np.array(c)

                # choose min(c) in the range of K/4 to K/3
                # see in https://github.com/yuanli2333/Hadamard-Matrix-for-hashing/issues/1
                # but it is hard when bit is  small
                if c.min() > bit / 4 and c.mean() >= bit / 2:
                    print(c.min(), c.mean())
                    break
        return hash_targets

# %%
# from torchvision import datasets, models, transforms

# model = models.resnet18(pretrained=True)
# num_ftrs = model.fc.in_features
# # Here the size of each output sample is set to 2.
# # Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
# model.fc = nn.Linear(num_ftrs, 450)

# %%
import numpy as np
import os
import cv2
from  matplotlib import pyplot as plt

## torch
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary

# dataset
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.nn import DataParallel
import tqdm


# read image
import PIL
from PIL import Image
from utils import *

ms_polyu_path = 'dataset/MS_PolyU/'
casia_path = 'dataset/CASIA-Multi-Spectral-PalmprintV1/images/'

r_img_path = ms_polyu_path + 'Red_ind/'
b_img_path =  ms_polyu_path + 'Blue_ind/'
n_img_path =  ms_polyu_path + 'NIR_ind/'
g_img_path =  ms_polyu_path + 'Green_ind/'

################ DATASET CLASS
def one_hot_embedding(labels, num_classes):
    """Embedding labels to one-hot form.

    Args:
      labels: (LongTensor) class labels, sized [N,].
      num_classes: (int) number of classes.

    Returns:
      (tensor) encoded labels, sized [N, #classes].
    """
    y = torch.eye(num_classes) 
    return y[labels] 
# one_hot_embedding(1, 10)
def part_init(istrain=True):
    r_list = []
    b_list = []
    vein_list = []
    prints_list = []
    labels = []
    
        # split all data into train, test data
    train_ratio = 1
    train_num = int(500 * train_ratio)
    print("split train users:",train_num)
    if istrain:
        for i in tqdm.tqdm(range(train_num)):
            for j in range(8):
                r_img = np.array(Image.open(os.path.join(r_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                r_normed = (r_img - r_img.min()) / (r_img.max()-r_img.min())
                
                g_img = np.array(Image.open(os.path.join(g_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                g_normed = (g_img - g_img.min()) / (g_img.max()-g_img.min())

                b_img = np.array(Image.open(os.path.join(b_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                b_normed = (b_img - b_img.min()) / (b_img.max()-b_img.min())

                n_img = np.array(Image.open(os.path.join(n_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                r_normed = (n_img - n_img.min()) / (n_img.max()-n_img.min())
                
                rb = r_normed - b_normed * 0.5
                rb =  (rb * 128+128).astype(np.uint8)

                imgprint = np.dstack((r_img,g_img,b_img))
                imgvein = np.dstack((rb, n_img))
                
                vein_list.append(imgvein)
                prints_list.append(imgprint)
                labels.append(one_hot_embedding(i, train_num))
#                 labels.append(i)
    else:
        for i in tqdm.tqdm(range(train_num)):
            for j in range(8,12):
                r_img = np.array(Image.open(os.path.join(r_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                r_normed = (r_img - r_img.min()) / (r_img.max()-r_img.min())
                
                g_img = np.array(Image.open(os.path.join(g_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                g_normed = (g_img - g_img.min()) / (g_img.max()-g_img.min())

                b_img = np.array(Image.open(os.path.join(b_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                b_normed = (b_img - b_img.min()) / (b_img.max()-b_img.min())

                n_img = np.array(Image.open(os.path.join(n_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
                r_normed = (n_img - n_img.min()) / (n_img.max()-n_img.min())
                
                rb = r_normed - b_normed * 0.5
                rb =  (rb * 128+128).astype(np.uint8)
                imgprint = np.dstack((r_img,g_img,b_img))
                imgvein = np.dstack((rb, n_img))
                
                vein_list.append(imgvein)
                prints_list.append(imgprint)
                labels.append(one_hot_embedding(i, train_num))
#                 labels.append(i)



    # return np.array(r_list), np.array(b_list), np.array(n_list), np.array(labels),np.array(r_list_test), np.array(b_list_test), np.array(n_list_test), np.array(labels_test)
    return  vein_list,prints_list, labels

# r_list, b_list, n_list, labels,r_list_test, b_list_test, n_list_test, labels_test = part_init()
class load_data(Dataset):
    """Loads the Data."""
    def __init__(self, training=True):

        self.training = training
#         r_list, b_list, n_list, labels,r_list_test, b_list_test, n_list_test, labels_test = part_init()
        self.transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.ColorJitter(),
        transforms.RandomRotation(degrees=15),
        transforms.RandomPerspective(),
        transforms.RandomAffine(30),
        transforms.ToTensor(),
#         transforms.Resize((224, 224)),# if resnet
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225]),
    ])
        self.transform_test = transforms.Compose([
        transforms.ToPILImage(),
#         transforms.Resize((224, 224)),# if resnet
        transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225]),
    ])
        if self.training:
            print('\n...... Train files loading\n')
            self.vein_list,self.prints_list, self.labels= part_init(istrain=True)
            print('\nTrain files loaded ......\n')
        else:
            print('\n...... Test files loading\n')
            self.vein_list,self.prints_list, self.labels = part_init(istrain=False)
            print('\nTest files loaded ......\n')

    def __len__(self):
        return len(self.vein_list)

         
    def __getitem__(self, idx):

        if self.training:
            prints_img = self.transform(self.prints_list[idx])
            vein_img = self.transform(self.vein_list[idx])
        else:
            prints_img = self.transform_test(self.prints_list[idx])
            vein_img = self.transform_test(self.vein_list[idx])
        
        label = self.labels[idx]
        
        n_img = np.dstack((prints_img[0,:,:],prints_img[1,:,:],prints_img[2,:,:],vein_img[0,:,:],vein_img[1,:,:]))
        
        return n_img,label

# %%
def get_config():
    config = {
        "lambda": 0.1,
        "optimizer": {"type": optim.RMSprop, "optim_params": {"lr": 1e-5, "weight_decay": 10 ** -5}},
        "info": "[CSQ]",
        "resize_size": 256,
        "crop_size": 224,
        "batch_size": 64,
        # "net": AlexNet,
        "net": "w",
        "dataset": "palmprint",
        "n_class":500,
        # "dataset": "imagenet",
        # "dataset": "coco",
        # "dataset": "nuswide_21",
        # "dataset": "nuswide_21_m",
        "epoch": 500,
        "test_map": 10,
        # "device":torch.device("cpu"),
        "device": torch.device("cuda:0"),
        "bit_list": [1024],
    }
#     config = config_dataset(config)
    return config



config = get_config()
print(config)
bit = 1024

device = config["device"]
# Out:
# {'lambda': 0.1, 'optimizer': {'type': <class 'torch.optim.rmsprop.RMSprop'>, 'optim_params': {'lr': 1e-05, 'weight_decay': 1e-05}}, 'info': '[CSQ]', 'resize_size': 256, 'crop_size': 224, 'batch_size': 64, 'net': 'w', 'dataset': 'palmprint', 'n_class': 500, 'epoch': 500, 'test_map': 10, 'device': device(type='cuda', index=0), 'bit_list': [1024]}

# %%
# train_loader, test_loader, dataset_loader, num_train, num_test, num_dataset = get_data(config)
batch_size = 256
train_loader = DataLoader(load_data(training=True), batch_size=batch_size, shuffle=True, num_workers=8, pin_memory=True,prefetch_factor=8)  # ,prefetch_factor=2
test_loader = DataLoader(load_data(training=False), batch_size=64, shuffle=False)  # ,prefetch_factor=2
# Out:
# ...... Train files loading
#
# split train users: 500
# 100%|██████████| 500/500 [00:50<00:00,  9.84it/s]
# Train files loaded ......
#
#
# ...... Test files loading
#
# split train users: 500
# 100%|██████████| 500/500 [01:41<00:00,  4.93it/s]
# Test files loaded ......

# %%
# batch_size = 32
dataset_loader = train_loader
num_train = 4000
num_test = 2000
num_dataset = 6000

# %%
from tools import *
# from network import *

import os
import torch
import torch.optim as optim
import time
import numpy as np
from scipy.linalg import hadamard  # direct import  hadamrd matrix from scipy
import random

torch.multiprocessing.set_sharing_strategy('file_system')


class CSQLoss(torch.nn.Module):
    def __init__(self, config, bit):
        super(CSQLoss, self).__init__()
        self.is_single_label = config["dataset"] not in {"nuswide_21", "nuswide_21_m", "coco"}
        self.hash_targets = self.get_hash_targets(config["n_class"], bit).to(config["device"])
        self.multi_label_random_center = torch.randint(2, (bit,)).float().to(config["device"])
        self.criterion = torch.nn.BCELoss().to(config["device"])

    def forward(self, u, y, ind, config):
        u = u.tanh()
        hash_center = self.label2center(y)
        center_loss = self.criterion(0.5 * (u + 1), 0.5 * (hash_center + 1))

        Q_loss = (u.abs() - 1).pow(2).mean()
        return center_loss + config["lambda"] * Q_loss

    def label2center(self, y):
        if self.is_single_label:
            hash_center = self.hash_targets[y.argmax(axis=1)]
        else:
            # to get sign no need to use mean, use sum here
            center_sum = y @ self.hash_targets
            random_center = self.multi_label_random_center.repeat(center_sum.shape[0], 1)
            center_sum[center_sum == 0] = random_center[center_sum == 0]
            hash_center = 2 * (center_sum > 0).float() - 1
        return hash_center

    # use algorithm 1 to generate hash centers
    def get_hash_targets(self, n_class, bit):
        H_K = hadamard(bit)
        H_2K = np.concatenate((H_K, -H_K), 0)
        hash_targets = torch.from_numpy(H_2K[:n_class]).float()

        if H_2K.shape[0] < n_class:
            hash_targets.resize_(n_class, bit)
            for k in range(20):
                for index in range(H_2K.shape[0], n_class):
                    ones = torch.ones(bit)
                    # Bernouli distribution
                    sa = random.sample(list(range(bit)), bit // 2)
                    ones[sa] = -1
                    hash_targets[index] = ones
                # to find average/min  pairwise distance
                c = []
                for i in range(n_class):
                    for j in range(n_class):
                        if i < j:
                            TF = sum(hash_targets[i] != hash_targets[j])
                            c.append(TF)
                c = np.array(c)

                # choose min(c) in the range of K/4 to K/3
                # see in https://github.com/yuanli2333/Hadamard-Matrix-for-hashing/issues/1
                # but it is hard when bit is  small
                if c.min() > bit / 4 and c.mean() >= bit / 2:
                    print(c.min(), c.mean())
                    break
        return hash_targets

# %%
# # Calculate the total parameters of the model
# print('Model size: {:0.2f} million float parameters'.format(get_parameters_size(model)/1e6))
# args.pretrained = 'model_best.pth.tar'
# if os.path.isfile(args.pretrained):
#     print("=> loading checkpoint '{}'".format(args.pretrained))
#     checkpoint = torch.load(args.pretrained)
#     model.load_state_dict(checkpoint['state_dict'])
# else:
#     print("=> no checkpoint found at '{}'".format(args.pretrained))

# %%
config["num_train"] = num_train
net = model.to(device)

# %%
optimizer = config["optimizer"]["type"](net.parameters(), **(config["optimizer"]["optim_params"]))

criterion = CSQLoss(config, bit)

# optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=args.momentum, weight_decay=3e-05)
scheduler = StepLR(optimizer, step_size=100, gamma=0.9)

# %%
import numpy as np

def normalized(a, axis=-1, order=2):
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2==0] = 1
    return a / np.expand_dims(l2, axis)

A = np.random.randn(1,2)*10
# print(A)
# print(normalized(A,0))
print(normalized(A,1))# ok verified
# print(normalized(A,2))
# from sklearn.preprocessing import normalize
# norm1 = A / np.linalg.norm(A)
# norm2 = normalize(A, axis=0).ravel()
# print(norm1)
# print(norm2)
# # print(normalized(np.arange(3)[:,None]))
# # print(normalized(np.arange(3)))
# eer = test(net,test_loader)
# Out:
# [[ 0.82469096 -0.56558362]]

# %%
def test(net,test_loader):
    test_loss = AverageMeter()
    acc = AverageMeter()
    FEATS = []
    GT = []
    features = {}
    with torch.no_grad():
        for batch_idx, img in enumerate(test_loader):
            rbn = img[0].permute(0, 3, 1, 2).to(device, dtype=torch.float)
            label = img[1].to(device)

            output = net(rbn)
            FEATS.append(output.cpu().numpy())
#             FEATS.append(features['feats'].cpu().numpy())
            GT.append(img[1].numpy())

    GCNFEATS = np.concatenate(FEATS)
    GT = np.concatenate(GT)
    GCNFEATS = normalized(GCNFEATS,1)
    print('- feats shape:', GCNFEATS.shape)
    print('- GT shape:', GT.shape)
    from numpy import dot
    from numpy.linalg import norm

    def cossim(a,b):
        return dot(a, b)/(norm(a)*norm(b))

    pred_scores = []
    gt_label = []

    for i in range(2000):
        for j in range(i+1,2000):
            # pred_scores.append(final[i,j].detach().cpu().numpy())
            a = cossim(GCNFEATS[i,:],GCNFEATS[j,:])
            pred_scores.append(a)
            gt_label.append(i//4 == j//4)

    pred_scores = np.array(pred_scores)
    gt_label = np.array(gt_label)

    Gen = pred_scores[gt_label]
    Imp = pred_scores[gt_label==False]
    Imp = Imp[np.random.permutation(len(Imp))[:len(Gen)]]


#     import seaborn as sns
#     sns.distplot(Gen,  kde=False, label='Gen')
#     # df =gapminder[gapminder.continent == 'Americas']
#     sns.distplot(Imp,  kde=False,label='Imp')
#     # Plot formatting
#     plt.legend(prop={'size': 12})
#     plt.title('Life Expectancy of Two Continents')
#     plt.xlabel('Life Exp (years)')
#     plt.ylabel('Density')

    from pyeer.eer_info import get_eer_stats
    from pyeer.report import generate_eer_report, export_error_rates
    from pyeer.plot import plot_eer_stats


    # Calculating stats for classifier A
    stats_a = get_eer_stats(Gen, Imp)
    print(stats_a.eer)

    return stats_a.eer

##### INSPECT FEATURES

# %%
Best_eer = 1.0
config["epoch"] = 2000
for epoch in range(500,config["epoch"]):

    current_time = time.strftime('%H:%M:%S', time.localtime(time.time()))

    print("%s[%2d/%2d][%s] bit:%d, dataset:%s, training...." % (
        config["info"], epoch + 1, config["epoch"], current_time, bit, config["dataset"]), end="")

    net.train()

    train_loss = 0
    for batch_idx, img in enumerate(train_loader):
        image = img[0].permute(0, 3, 1, 2).to(device, dtype=torch.float)
        label = img[1].to(device)

        optimizer.zero_grad()
        u = net(image)

        loss = criterion(u, label.float(), 0, config)
        train_loss += loss.item()

        loss.backward()
        optimizer.step()

    train_loss = train_loss / len(train_loader)
    if epoch % 50 ==0:
        eer = test(net,test_loader)
        if eer < Best_eer:
            Best_eer = eer
            save_checkpoint({
                'epoch': epoch + 1,
                'state_dict': net.state_dict(),
                'best_prec1': Best_eer,
                'optimizer' : optimizer.state_dict(),
            }, True,remark='GCN2wayCAHashing')
        print("%s epoch:%d, bit:%d, dataset:%s,eer:%.5f, Best eer: %.5f" % (
            config["info"], epoch + 1, bit, config["dataset"], eer, Best_eer))
    print("\b\b\b\b\b\b\b loss:%.5f" % (train_loss))##loss:0.625
    scheduler.step()

#     if (epoch + 1) % config["test_map"] == 0:
#         # print("calculating test binary code......")
#         tst_binary, tst_label = compute_result(test_loader, net, device=device)

#         # print("calculating dataset binary code.......")\
#         trn_binary, trn_label = compute_result(dataset_loader, net, device=device)

#         # print("calculating map.......")
#         mAP = CalcTopMap(trn_binary.numpy(), tst_binary.numpy(), trn_label.numpy(), tst_label.numpy(),
#                          config["topK"])

#         if mAP > Best_mAP:
#             Best_mAP = mAP

#             if "save_path" in config:
#                 if not os.path.exists(config["save_path"]):
#                     os.makedirs(config["save_path"])
#                 print("save in ", config["save_path"])
#                 np.save(os.path.join(config["save_path"], config["dataset"] + str(mAP) + "-" + "trn_binary.npy"),
#                         trn_binary.numpy())
#                 torch.save(net.state_dict(),
#                            os.path.join(config["save_path"], config["dataset"] + "-" + str(mAP) + "-model.pt"))
#         print("%s epoch:%d, bit:%d, dataset:%s, MAP:%.3f, Best MAP: %.3f" % (
#             config["info"], epoch + 1, bit, config["dataset"], mAP, Best_mAP))
#         print(config)
# Out:
# [CSQ][501/2000][11:47:53] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.010333333333333333
# [CSQ] epoch:501, bit:1024, dataset:palmprint,eer:0.01033, Best eer: 0.01033
#  loss:0.70341
# [CSQ][502/2000][11:49:09] bit:1024, dataset:palmprint, training... loss:0.70364
# [CSQ][503/2000][11:49:20] bit:1024, dataset:palmprint, training... loss:0.70367
# [CSQ][504/2000][11:49:31] bit:1024, dataset:palmprint, training... loss:0.70352
# [CSQ][505/2000][11:49:41] bit:1024, dataset:palmprint, training... loss:0.70275
# [CSQ][506/2000][11:49:52] bit:1024, dataset:palmprint, training... loss:0.70295
# [CSQ][507/2000][11:50:02] bit:1024, dataset:palmprint, training... loss:0.70333
# [CSQ][508/2000][11:50:12] bit:1024, dataset:palmprint, training... loss:0.70335
# [CSQ][509/2000][11:50:22] bit:1024, dataset:palmprint, training... loss:0.70321
# [CSQ][510/2000][11:50:31] bit:1024, dataset:palmprint, training... loss:0.70327
# [CSQ][511/2000][11:50:41] bit:1024, dataset:palmprint, training... loss:0.70313
# [CSQ][512/2000][11:50:51] bit:1024, dataset:palmprint, training... loss:0.70351
# [CSQ][513/2000][11:51:01] bit:1024, dataset:palmprint, training... loss:0.70300
# [CSQ][514/2000][11:51:11] bit:1024, dataset:palmprint, training... loss:0.70281
# [CSQ][515/2000][11:51:22] bit:1024, dataset:palmprint, training... loss:0.70275
# [CSQ][516/2000][11:51:32] bit:1024, dataset:palmprint, training... loss:0.70323
# [CSQ][517/2000][11:51:42] bit:1024, dataset:palmprint, training... loss:0.70356
# [CSQ][518/2000][11:51:52] bit:1024, dataset:palmprint, training... loss:0.70290
# [CSQ][519/2000][11:52:02] bit:1024, dataset:palmprint, training... loss:0.70287
# [CSQ][520/2000][11:52:13] bit:1024, dataset:palmprint, training... loss:0.70278
# [CSQ][521/2000][11:52:24] bit:1024, dataset:palmprint, training... loss:0.70284
# [CSQ][522/2000][11:52:36] bit:1024, dataset:palmprint, training... loss:0.70305
# [CSQ][523/2000][11:52:47] bit:1024, dataset:palmprint, training... loss:0.70264
# [CSQ][524/2000][11:52:58] bit:1024, dataset:palmprint, training... loss:0.70289
# [CSQ][525/2000][11:53:08] bit:1024, dataset:palmprint, training... loss:0.70242
# [CSQ][526/2000][11:53:18] bit:1024, dataset:palmprint, training... loss:0.70274
# [CSQ][527/2000][11:53:28] bit:1024, dataset:palmprint, training... loss:0.70232
# [CSQ][528/2000][11:53:38] bit:1024, dataset:palmprint, training... loss:0.70214
# [CSQ][529/2000][11:53:48] bit:1024, dataset:palmprint, training... loss:0.70236
# [CSQ][530/2000][11:53:58] bit:1024, dataset:palmprint, training... loss:0.70274
# [CSQ][531/2000][11:54:08] bit:1024, dataset:palmprint, training... loss:0.70247
# [CSQ][532/2000][11:54:17] bit:1024, dataset:palmprint, training... loss:0.70220
# [CSQ][533/2000][11:54:27] bit:1024, dataset:palmprint, training... loss:0.70229
# [CSQ][534/2000][11:54:36] bit:1024, dataset:palmprint, training... loss:0.70187
# [CSQ][535/2000][11:54:45] bit:1024, dataset:palmprint, training... loss:0.70224
# [CSQ][536/2000][11:54:54] bit:1024, dataset:palmprint, training... loss:0.70227
# [CSQ][537/2000][11:55:03] bit:1024, dataset:palmprint, training... loss:0.70241
# [CSQ][538/2000][11:55:13] bit:1024, dataset:palmprint, training... loss:0.70271
# [CSQ][539/2000][11:55:22] bit:1024, dataset:palmprint, training... loss:0.70252
# [CSQ][540/2000][11:55:32] bit:1024, dataset:palmprint, training... loss:0.70230
# [CSQ][541/2000][11:55:41] bit:1024, dataset:palmprint, training... loss:0.70228
# [CSQ][542/2000][11:55:51] bit:1024, dataset:palmprint, training... loss:0.70218
# [CSQ][543/2000][11:56:00] bit:1024, dataset:palmprint, training... loss:0.70174
# [CSQ][544/2000][11:56:10] bit:1024, dataset:palmprint, training... loss:0.70196
# [CSQ][545/2000][11:56:19] bit:1024, dataset:palmprint, training... loss:0.70187
# [CSQ][546/2000][11:56:29] bit:1024, dataset:palmprint, training... loss:0.70214
# [CSQ][547/2000][11:56:38] bit:1024, dataset:palmprint, training... loss:0.70218
# [CSQ][548/2000][11:56:48] bit:1024, dataset:palmprint, training... loss:0.70191
# [CSQ][549/2000][11:56:57] bit:1024, dataset:palmprint, training... loss:0.70133
# [CSQ][550/2000][11:57:07] bit:1024, dataset:palmprint, training... loss:0.70167
# [CSQ][551/2000][11:57:20] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.011666666666666667
# [CSQ] epoch:551, bit:1024, dataset:palmprint,eer:0.01167, Best eer: 0.01033
#  loss:0.70171
# [CSQ][552/2000][11:58:29] bit:1024, dataset:palmprint, training... loss:0.70206
# [CSQ][553/2000][11:58:40] bit:1024, dataset:palmprint, training... loss:0.70165
# [CSQ][554/2000][11:58:51] bit:1024, dataset:palmprint, training... loss:0.70208
# [CSQ][555/2000][11:59:01] bit:1024, dataset:palmprint, training... loss:0.70142
# [CSQ][556/2000][11:59:11] bit:1024, dataset:palmprint, training... loss:0.70166
# [CSQ][557/2000][11:59:21] bit:1024, dataset:palmprint, training... loss:0.70143
# [CSQ][558/2000][11:59:32] bit:1024, dataset:palmprint, training... loss:0.70180
# [CSQ][559/2000][11:59:43] bit:1024, dataset:palmprint, training... loss:0.70167
# [CSQ][560/2000][11:59:54] bit:1024, dataset:palmprint, training... loss:0.70160
# [CSQ][561/2000][12:00:06] bit:1024, dataset:palmprint, training... loss:0.70152
# [CSQ][562/2000][12:00:18] bit:1024, dataset:palmprint, training... loss:0.70133
# [CSQ][563/2000][12:00:28] bit:1024, dataset:palmprint, training... loss:0.70162
# [CSQ][564/2000][12:00:38] bit:1024, dataset:palmprint, training... loss:0.70163
# [CSQ][565/2000][12:00:48] bit:1024, dataset:palmprint, training... loss:0.70113
# [CSQ][566/2000][12:00:57] bit:1024, dataset:palmprint, training... loss:0.70083
# [CSQ][567/2000][12:01:07] bit:1024, dataset:palmprint, training... loss:0.70095
# [CSQ][568/2000][12:01:17] bit:1024, dataset:palmprint, training... loss:0.70141
# [CSQ][569/2000][12:01:27] bit:1024, dataset:palmprint, training... loss:0.70112
# [CSQ][570/2000][12:01:37] bit:1024, dataset:palmprint, training... loss:0.70083
# [CSQ][571/2000][12:01:47] bit:1024, dataset:palmprint, training... loss:0.70094
# [CSQ][572/2000][12:01:58] bit:1024, dataset:palmprint, training... loss:0.70102
# [CSQ][573/2000][12:02:09] bit:1024, dataset:palmprint, training... loss:0.70162
# [CSQ][574/2000][12:02:21] bit:1024, dataset:palmprint, training... loss:0.70129
# [CSQ][575/2000][12:02:33] bit:1024, dataset:palmprint, training... loss:0.70127
# [CSQ][576/2000][12:02:44] bit:1024, dataset:palmprint, training... loss:0.70094
# [CSQ][577/2000][12:02:54] bit:1024, dataset:palmprint, training... loss:0.70076
# [CSQ][578/2000][12:03:04] bit:1024, dataset:palmprint, training... loss:0.70106
# [CSQ][579/2000][12:03:14] bit:1024, dataset:palmprint, training... loss:0.70098
# [CSQ][580/2000][12:03:24] bit:1024, dataset:palmprint, training... loss:0.70067
# [CSQ][581/2000][12:03:34] bit:1024, dataset:palmprint, training... loss:0.70122
# [CSQ][582/2000][12:03:44] bit:1024, dataset:palmprint, training... loss:0.70088
# [CSQ][583/2000][12:03:54] bit:1024, dataset:palmprint, training... loss:0.70035
# [CSQ][584/2000][12:04:05] bit:1024, dataset:palmprint, training... loss:0.70083
# [CSQ][585/2000][12:04:16] bit:1024, dataset:palmprint, training... loss:0.70045
# [CSQ][586/2000][12:04:27] bit:1024, dataset:palmprint, training... loss:0.70052
# [CSQ][587/2000][12:04:37] bit:1024, dataset:palmprint, training... loss:0.70006
# [CSQ][588/2000][12:04:49] bit:1024, dataset:palmprint, training... loss:0.70049
# [CSQ][589/2000][12:05:00] bit:1024, dataset:palmprint, training... loss:0.70093
# [CSQ][590/2000][12:05:12] bit:1024, dataset:palmprint, training... loss:0.70025
# [CSQ][591/2000][12:05:22] bit:1024, dataset:palmprint, training... loss:0.70073
# [CSQ][592/2000][12:05:33] bit:1024, dataset:palmprint, training... loss:0.70060
# [CSQ][593/2000][12:05:42] bit:1024, dataset:palmprint, training... loss:0.70004
# [CSQ][594/2000][12:05:52] bit:1024, dataset:palmprint, training... loss:0.70040
# [CSQ][595/2000][12:06:02] bit:1024, dataset:palmprint, training... loss:0.70076
# [CSQ][596/2000][12:06:12] bit:1024, dataset:palmprint, training... loss:0.70017
# [CSQ][597/2000][12:06:27] bit:1024, dataset:palmprint, training... loss:0.70021
# [CSQ][598/2000][12:06:37] bit:1024, dataset:palmprint, training... loss:0.70084
# [CSQ][599/2000][12:06:46] bit:1024, dataset:palmprint, training... loss:0.69998
# [CSQ][600/2000][12:06:56] bit:1024, dataset:palmprint, training... loss:0.69983
# [CSQ][601/2000][12:07:06] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.010666666666666666
# [CSQ] epoch:601, bit:1024, dataset:palmprint,eer:0.01067, Best eer: 0.01033
#  loss:0.70052
# [CSQ][602/2000][12:08:16] bit:1024, dataset:palmprint, training... loss:0.70053
# [CSQ][603/2000][12:08:28] bit:1024, dataset:palmprint, training... loss:0.70026
# [CSQ][604/2000][12:08:38] bit:1024, dataset:palmprint, training... loss:0.70047
# [CSQ][605/2000][12:08:48] bit:1024, dataset:palmprint, training... loss:0.70013
# [CSQ][606/2000][12:08:58] bit:1024, dataset:palmprint, training... loss:0.69964
# [CSQ][607/2000][12:09:08] bit:1024, dataset:palmprint, training... loss:0.69963
# [CSQ][608/2000][12:09:18] bit:1024, dataset:palmprint, training... loss:0.69952
# [CSQ][609/2000][12:09:28] bit:1024, dataset:palmprint, training... loss:0.70056
# [CSQ][610/2000][12:09:38] bit:1024, dataset:palmprint, training... loss:0.70016
# [CSQ][611/2000][12:09:48] bit:1024, dataset:palmprint, training... loss:0.69979
# [CSQ][612/2000][12:09:58] bit:1024, dataset:palmprint, training... loss:0.70000
# [CSQ][613/2000][12:10:09] bit:1024, dataset:palmprint, training... loss:0.69949
# [CSQ][614/2000][12:10:19] bit:1024, dataset:palmprint, training... loss:0.69994
# [CSQ][615/2000][12:10:30] bit:1024, dataset:palmprint, training... loss:0.70003
# [CSQ][616/2000][12:10:41] bit:1024, dataset:palmprint, training... loss:0.69961
# [CSQ][617/2000][12:10:54] bit:1024, dataset:palmprint, training... loss:0.69978
# [CSQ][618/2000][12:11:05] bit:1024, dataset:palmprint, training... loss:0.69974
# [CSQ][619/2000][12:11:16] bit:1024, dataset:palmprint, training... loss:0.69977
# [CSQ][620/2000][12:11:26] bit:1024, dataset:palmprint, training... loss:0.69950
# [CSQ][621/2000][12:11:36] bit:1024, dataset:palmprint, training... loss:0.69924
# [CSQ][622/2000][12:11:46] bit:1024, dataset:palmprint, training... loss:0.69959
# [CSQ][623/2000][12:11:56] bit:1024, dataset:palmprint, training... loss:0.69962
# [CSQ][624/2000][12:12:05] bit:1024, dataset:palmprint, training... loss:0.69919
# [CSQ][625/2000][12:12:15] bit:1024, dataset:palmprint, training... loss:0.69971
# [CSQ][626/2000][12:12:26] bit:1024, dataset:palmprint, training... loss:0.69935
# [CSQ][627/2000][12:12:36] bit:1024, dataset:palmprint, training... loss:0.69983
# [CSQ][628/2000][12:12:47] bit:1024, dataset:palmprint, training... loss:0.69929
# [CSQ][629/2000][12:12:59] bit:1024, dataset:palmprint, training... loss:0.69953
# [CSQ][630/2000][12:13:10] bit:1024, dataset:palmprint, training... loss:0.69947
# [CSQ][631/2000][12:13:22] bit:1024, dataset:palmprint, training... loss:0.69862
# [CSQ][632/2000][12:13:32] bit:1024, dataset:palmprint, training... loss:0.69912
# [CSQ][633/2000][12:13:42] bit:1024, dataset:palmprint, training... loss:0.69981
# [CSQ][634/2000][12:13:53] bit:1024, dataset:palmprint, training... loss:0.69937
# [CSQ][635/2000][12:14:03] bit:1024, dataset:palmprint, training... loss:0.69901
# [CSQ][636/2000][12:14:13] bit:1024, dataset:palmprint, training... loss:0.69970
# [CSQ][637/2000][12:14:23] bit:1024, dataset:palmprint, training... loss:0.69928
# [CSQ][638/2000][12:14:33] bit:1024, dataset:palmprint, training... loss:0.69883
# [CSQ][639/2000][12:14:43] bit:1024, dataset:palmprint, training... loss:0.69919
# [CSQ][640/2000][12:14:53] bit:1024, dataset:palmprint, training... loss:0.69867
# [CSQ][641/2000][12:15:03] bit:1024, dataset:palmprint, training... loss:0.69908
# [CSQ][642/2000][12:15:14] bit:1024, dataset:palmprint, training... loss:0.69898
# [CSQ][643/2000][12:15:24] bit:1024, dataset:palmprint, training... loss:0.69901
# [CSQ][644/2000][12:15:40] bit:1024, dataset:palmprint, training... loss:0.69851
# [CSQ][645/2000][12:15:50] bit:1024, dataset:palmprint, training... loss:0.69869
# [CSQ][646/2000][12:16:00] bit:1024, dataset:palmprint, training... loss:0.69869
# [CSQ][647/2000][12:16:10] bit:1024, dataset:palmprint, training... loss:0.69873
# [CSQ][648/2000][12:16:20] bit:1024, dataset:palmprint, training... loss:0.69856
# [CSQ][649/2000][12:16:29] bit:1024, dataset:palmprint, training... loss:0.69888
# [CSQ][650/2000][12:16:39] bit:1024, dataset:palmprint, training... loss:0.69893
# [CSQ][651/2000][12:16:50] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.011
# [CSQ] epoch:651, bit:1024, dataset:palmprint,eer:0.01100, Best eer: 0.01033
#  loss:0.69878
# [CSQ][652/2000][12:18:11] bit:1024, dataset:palmprint, training... loss:0.69925
# [CSQ][653/2000][12:18:22] bit:1024, dataset:palmprint, training... loss:0.69891
# [CSQ][654/2000][12:18:32] bit:1024, dataset:palmprint, training... loss:0.69821
# [CSQ][655/2000][12:18:42] bit:1024, dataset:palmprint, training... loss:0.69833
# [CSQ][656/2000][12:18:53] bit:1024, dataset:palmprint, training... loss:0.69874
# [CSQ][657/2000][12:19:03] bit:1024, dataset:palmprint, training... loss:0.69918
# [CSQ][658/2000][12:19:14] bit:1024, dataset:palmprint, training... loss:0.69814
# [CSQ][659/2000][12:19:25] bit:1024, dataset:palmprint, training... loss:0.69852
# [CSQ][660/2000][12:19:35] bit:1024, dataset:palmprint, training... loss:0.69804
# [CSQ][661/2000][12:19:46] bit:1024, dataset:palmprint, training... loss:0.69874
# [CSQ][662/2000][12:19:57] bit:1024, dataset:palmprint, training... loss:0.69860
# [CSQ][663/2000][12:20:07] bit:1024, dataset:palmprint, training... loss:0.69860
# [CSQ][664/2000][12:20:18] bit:1024, dataset:palmprint, training... loss:0.69819
# [CSQ][665/2000][12:20:28] bit:1024, dataset:palmprint, training... loss:0.69831
# [CSQ][666/2000][12:20:38] bit:1024, dataset:palmprint, training... loss:0.69844
# [CSQ][667/2000][12:20:48] bit:1024, dataset:palmprint, training... loss:0.69837
# [CSQ][668/2000][12:20:58] bit:1024, dataset:palmprint, training... loss:0.69781
# [CSQ][669/2000][12:21:08] bit:1024, dataset:palmprint, training... loss:0.69758
# [CSQ][670/2000][12:21:18] bit:1024, dataset:palmprint, training... loss:0.69756
# [CSQ][671/2000][12:21:28] bit:1024, dataset:palmprint, training... loss:0.69829
# [CSQ][672/2000][12:21:38] bit:1024, dataset:palmprint, training... loss:0.69847
# [CSQ][673/2000][12:21:47] bit:1024, dataset:palmprint, training... loss:0.69801
# [CSQ][674/2000][12:21:58] bit:1024, dataset:palmprint, training... loss:0.69763
# [CSQ][675/2000][12:22:08] bit:1024, dataset:palmprint, training... loss:0.69805
# [CSQ][676/2000][12:22:19] bit:1024, dataset:palmprint, training... loss:0.69822
# [CSQ][677/2000][12:22:31] bit:1024, dataset:palmprint, training... loss:0.69825
# [CSQ][678/2000][12:22:44] bit:1024, dataset:palmprint, training... loss:0.69742
# [CSQ][679/2000][12:22:55] bit:1024, dataset:palmprint, training... loss:0.69801
# [CSQ][680/2000][12:23:05] bit:1024, dataset:palmprint, training... loss:0.69771
# [CSQ][681/2000][12:23:16] bit:1024, dataset:palmprint, training... loss:0.69831
# [CSQ][682/2000][12:23:26] bit:1024, dataset:palmprint, training... loss:0.69735
# [CSQ][683/2000][12:23:37] bit:1024, dataset:palmprint, training... loss:0.69744
# [CSQ][684/2000][12:23:47] bit:1024, dataset:palmprint, training... loss:0.69802
# [CSQ][685/2000][12:23:58] bit:1024, dataset:palmprint, training... loss:0.69788
# [CSQ][686/2000][12:24:08] bit:1024, dataset:palmprint, training... loss:0.69759
# [CSQ][687/2000][12:24:19] bit:1024, dataset:palmprint, training... loss:0.69785
# [CSQ][688/2000][12:24:29] bit:1024, dataset:palmprint, training... loss:0.69770
# [CSQ][689/2000][12:24:40] bit:1024, dataset:palmprint, training... loss:0.69708
# [CSQ][690/2000][12:24:52] bit:1024, dataset:palmprint, training... loss:0.69775
# [CSQ][691/2000][12:25:08] bit:1024, dataset:palmprint, training... loss:0.69763
# [CSQ][692/2000][12:25:18] bit:1024, dataset:palmprint, training... loss:0.69692
# [CSQ][693/2000][12:25:28] bit:1024, dataset:palmprint, training... loss:0.69722
# [CSQ][694/2000][12:25:38] bit:1024, dataset:palmprint, training... loss:0.69746
# [CSQ][695/2000][12:25:48] bit:1024, dataset:palmprint, training... loss:0.69779
# [CSQ][696/2000][12:25:58] bit:1024, dataset:palmprint, training... loss:0.69709
# [CSQ][697/2000][12:26:08] bit:1024, dataset:palmprint, training... loss:0.69723
# [CSQ][698/2000][12:26:19] bit:1024, dataset:palmprint, training... loss:0.69727
# [CSQ][699/2000][12:26:29] bit:1024, dataset:palmprint, training... loss:0.69703
# [CSQ][700/2000][12:26:39] bit:1024, dataset:palmprint, training... loss:0.69759
# [CSQ][701/2000][12:26:49] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.009666666666666667
# [CSQ] epoch:701, bit:1024, dataset:palmprint,eer:0.00967, Best eer: 0.00967
#  loss:0.69757
# [CSQ][702/2000][12:28:07] bit:1024, dataset:palmprint, training... loss:0.69739
# [CSQ][703/2000][12:28:18] bit:1024, dataset:palmprint, training... loss:0.69666
# [CSQ][704/2000][12:28:28] bit:1024, dataset:palmprint, training... loss:0.69722
# [CSQ][705/2000][12:28:38] bit:1024, dataset:palmprint, training... loss:0.69700
# [CSQ][706/2000][12:28:48] bit:1024, dataset:palmprint, training... loss:0.69708
# [CSQ][707/2000][12:28:58] bit:1024, dataset:palmprint, training... loss:0.69750
# [CSQ][708/2000][12:29:08] bit:1024, dataset:palmprint, training... loss:0.69677
# [CSQ][709/2000][12:29:18] bit:1024, dataset:palmprint, training... loss:0.69657
# [CSQ][710/2000][12:29:29] bit:1024, dataset:palmprint, training... loss:0.69682
# [CSQ][711/2000][12:29:39] bit:1024, dataset:palmprint, training... loss:0.69698
# [CSQ][712/2000][12:29:50] bit:1024, dataset:palmprint, training... loss:0.69683
# [CSQ][713/2000][12:30:00] bit:1024, dataset:palmprint, training... loss:0.69687
# [CSQ][714/2000][12:30:11] bit:1024, dataset:palmprint, training... loss:0.69714
# [CSQ][715/2000][12:30:23] bit:1024, dataset:palmprint, training... loss:0.69644
# [CSQ][716/2000][12:30:35] bit:1024, dataset:palmprint, training... loss:0.69671
# [CSQ][717/2000][12:30:48] bit:1024, dataset:palmprint, training... loss:0.69681
# [CSQ][718/2000][12:30:58] bit:1024, dataset:palmprint, training... loss:0.69697
# [CSQ][719/2000][12:31:09] bit:1024, dataset:palmprint, training... loss:0.69694
# [CSQ][720/2000][12:31:19] bit:1024, dataset:palmprint, training... loss:0.69679
# [CSQ][721/2000][12:31:29] bit:1024, dataset:palmprint, training... loss:0.69681
# [CSQ][722/2000][12:31:39] bit:1024, dataset:palmprint, training... loss:0.69646
# [CSQ][723/2000][12:31:50] bit:1024, dataset:palmprint, training... loss:0.69684
# [CSQ][724/2000][12:32:01] bit:1024, dataset:palmprint, training... loss:0.69620
# [CSQ][725/2000][12:32:12] bit:1024, dataset:palmprint, training... loss:0.69633
# [CSQ][726/2000][12:32:24] bit:1024, dataset:palmprint, training... loss:0.69598
# [CSQ][727/2000][12:32:36] bit:1024, dataset:palmprint, training... loss:0.69657
# [CSQ][728/2000][12:32:47] bit:1024, dataset:palmprint, training... loss:0.69591
# [CSQ][729/2000][12:32:58] bit:1024, dataset:palmprint, training... loss:0.69653
# [CSQ][730/2000][12:33:08] bit:1024, dataset:palmprint, training... loss:0.69617
# [CSQ][731/2000][12:33:18] bit:1024, dataset:palmprint, training... loss:0.69685
# [CSQ][732/2000][12:33:29] bit:1024, dataset:palmprint, training... loss:0.69623
# [CSQ][733/2000][12:33:39] bit:1024, dataset:palmprint, training... loss:0.69633
# [CSQ][734/2000][12:33:48] bit:1024, dataset:palmprint, training... loss:0.69618
# [CSQ][735/2000][12:33:58] bit:1024, dataset:palmprint, training... loss:0.69669
# [CSQ][736/2000][12:34:08] bit:1024, dataset:palmprint, training... loss:0.69614
# [CSQ][737/2000][12:34:25] bit:1024, dataset:palmprint, training... loss:0.69641
# [CSQ][738/2000][12:34:37] bit:1024, dataset:palmprint, training... loss:0.69584
# [CSQ][739/2000][12:34:47] bit:1024, dataset:palmprint, training... loss:0.69658
# [CSQ][740/2000][12:34:57] bit:1024, dataset:palmprint, training... loss:0.69570
# [CSQ][741/2000][12:35:07] bit:1024, dataset:palmprint, training... loss:0.69641
# [CSQ][742/2000][12:35:16] bit:1024, dataset:palmprint, training... loss:0.69667
# [CSQ][743/2000][12:35:26] bit:1024, dataset:palmprint, training... loss:0.69619
# [CSQ][744/2000][12:35:35] bit:1024, dataset:palmprint, training... loss:0.69596
# [CSQ][745/2000][12:35:45] bit:1024, dataset:palmprint, training... loss:0.69576
# [CSQ][746/2000][12:35:55] bit:1024, dataset:palmprint, training... loss:0.69618
# [CSQ][747/2000][12:36:06] bit:1024, dataset:palmprint, training... loss:0.69610
# [CSQ][748/2000][12:36:16] bit:1024, dataset:palmprint, training... loss:0.69575
# [CSQ][749/2000][12:36:26] bit:1024, dataset:palmprint, training... loss:0.69581
# [CSQ][750/2000][12:36:37] bit:1024, dataset:palmprint, training... loss:0.69643
# [CSQ][751/2000][12:36:47] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.010333333333333333
# [CSQ] epoch:751, bit:1024, dataset:palmprint,eer:0.01033, Best eer: 0.00967
#  loss:0.69604
# [CSQ][752/2000][12:38:05] bit:1024, dataset:palmprint, training... loss:0.69613
# [CSQ][753/2000][12:38:16] bit:1024, dataset:palmprint, training... loss:0.69608
# [CSQ][754/2000][12:38:29] bit:1024, dataset:palmprint, training... loss:0.69603
# [CSQ][755/2000][12:38:39] bit:1024, dataset:palmprint, training... loss:0.69596
# [CSQ][756/2000][12:38:50] bit:1024, dataset:palmprint, training... loss:0.69577
# [CSQ][757/2000][12:39:05] bit:1024, dataset:palmprint, training... loss:0.69588
# [CSQ][758/2000][12:39:16] bit:1024, dataset:palmprint, training... loss:0.69607
# [CSQ][759/2000][12:39:30] bit:1024, dataset:palmprint, training... loss:0.69586
# [CSQ][760/2000][12:39:42] bit:1024, dataset:palmprint, training... loss:0.69637
# [CSQ][761/2000][12:39:54] bit:1024, dataset:palmprint, training... loss:0.69573
# [CSQ][762/2000][12:40:05] bit:1024, dataset:palmprint, training... loss:0.69568
# [CSQ][763/2000][12:40:16] bit:1024, dataset:palmprint, training... loss:0.69537
# [CSQ][764/2000][12:40:26] bit:1024, dataset:palmprint, training... loss:0.69603
# [CSQ][765/2000][12:40:36] bit:1024, dataset:palmprint, training... loss:0.69531
# [CSQ][766/2000][12:40:46] bit:1024, dataset:palmprint, training... loss:0.69558
# [CSQ][767/2000][12:40:56] bit:1024, dataset:palmprint, training... loss:0.69547
# [CSQ][768/2000][12:41:06] bit:1024, dataset:palmprint, training... loss:0.69573
# [CSQ][769/2000][12:41:16] bit:1024, dataset:palmprint, training... loss:0.69546
# [CSQ][770/2000][12:41:27] bit:1024, dataset:palmprint, training... loss:0.69532
# [CSQ][771/2000][12:41:42] bit:1024, dataset:palmprint, training... loss:0.69538
# [CSQ][772/2000][12:41:51] bit:1024, dataset:palmprint, training... loss:0.69562
# [CSQ][773/2000][12:42:02] bit:1024, dataset:palmprint, training... loss:0.69516
# [CSQ][774/2000][12:42:12] bit:1024, dataset:palmprint, training... loss:0.69509
# [CSQ][775/2000][12:42:22] bit:1024, dataset:palmprint, training... loss:0.69582
# [CSQ][776/2000][12:42:32] bit:1024, dataset:palmprint, training... loss:0.69575
# [CSQ][777/2000][12:42:42] bit:1024, dataset:palmprint, training... loss:0.69500
# [CSQ][778/2000][12:42:55] bit:1024, dataset:palmprint, training... loss:0.69528
# [CSQ][779/2000][12:43:06] bit:1024, dataset:palmprint, training... loss:0.69576
# [CSQ][780/2000][12:43:17] bit:1024, dataset:palmprint, training... loss:0.69491
# [CSQ][781/2000][12:43:29] bit:1024, dataset:palmprint, training... loss:0.69509
# [CSQ][782/2000][12:43:42] bit:1024, dataset:palmprint, training... loss:0.69469
# [CSQ][783/2000][12:43:53] bit:1024, dataset:palmprint, training... loss:0.69505
# [CSQ][784/2000][12:44:04] bit:1024, dataset:palmprint, training... loss:0.69521
# [CSQ][785/2000][12:44:17] bit:1024, dataset:palmprint, training... loss:0.69518
# [CSQ][786/2000][12:44:33] bit:1024, dataset:palmprint, training... loss:0.69484
# [CSQ][787/2000][12:44:43] bit:1024, dataset:palmprint, training... loss:0.69531
# [CSQ][788/2000][12:44:52] bit:1024, dataset:palmprint, training... loss:0.69522
# [CSQ][789/2000][12:45:02] bit:1024, dataset:palmprint, training... loss:0.69522
# [CSQ][790/2000][12:45:12] bit:1024, dataset:palmprint, training... loss:0.69479
# [CSQ][791/2000][12:45:21] bit:1024, dataset:palmprint, training... loss:0.69488
# [CSQ][792/2000][12:45:31] bit:1024, dataset:palmprint, training... loss:0.69438
# [CSQ][793/2000][12:45:42] bit:1024, dataset:palmprint, training... loss:0.69479
# [CSQ][794/2000][12:45:52] bit:1024, dataset:palmprint, training... loss:0.69431
# [CSQ][795/2000][12:46:02] bit:1024, dataset:palmprint, training... loss:0.69482
# [CSQ][796/2000][12:46:12] bit:1024, dataset:palmprint, training... loss:0.69441
# [CSQ][797/2000][12:46:23] bit:1024, dataset:palmprint, training... loss:0.69445
# [CSQ][798/2000][12:46:33] bit:1024, dataset:palmprint, training... loss:0.69476
# [CSQ][799/2000][12:46:44] bit:1024, dataset:palmprint, training... loss:0.69484
# [CSQ][800/2000][12:46:56] bit:1024, dataset:palmprint, training... loss:0.69510
# [CSQ][801/2000][12:47:07] bit:1024, dataset:palmprint, training....- feats shape: (2000, 1024)
# - GT shape: (2000, 500)
# 0.011
# [CSQ] epoch:801, bit:1024, dataset:palmprint,eer:0.01100, Best eer: 0.00967
#  loss:0.69469
# [CSQ][802/2000][12:48:34] bit:1024, dataset:palmprint, training... loss:0.69427
# [CSQ][803/2000][12:48:45] bit:1024, dataset:palmprint, training... loss:0.69447
# [CSQ][804/2000][12:48:55] bit:1024, dataset:palmprint, training... loss:0.69478
# [CSQ][805/2000][12:49:05] bit:1024, dataset:palmprint, training... loss:0.69476
# [CSQ][806/2000][12:49:15] bit:1024, dataset:palmprint, training... loss:0.69470
# [CSQ][807/2000][12:49:25] bit:1024, dataset:palmprint, training... loss:0.69446
# [CSQ][808/2000][12:49:37] bit:1024, dataset:palmprint, training... loss:0.69416
# [CSQ][809/2000][12:49:47] bit:1024, dataset:palmprint, training....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_404/2530210305.py in <module>
#      12     train_loss = 0
#      13     for batch_idx, img in enumerate(train_loader):
# ---> 14         image = img[0].permute(0, 3, 1, 2).to(device, dtype=torch.float)
#      15         label = img[1].to(device)
#      16
#
# KeyboardInterrupt:

# %% [markdown]
# 0.025666666666666667  0.01 lamda "lr": 1e-5

# %%
# # if epoch % 50 ==0:
# save_checkpoint({
#     'epoch': epoch + 1,
#     'state_dict': net.state_dict(),
#     'best_prec1': 0,
#     'optimizer' : optimizer.state_dict(),
# }, True)

# %%
# for _, img in tqdm.tqdm(enumerate(train_loader)):
#     print((img[0].size(), img[1].size()))
#     break
    
# for _, img in tqdm.tqdm(enumerate(test_loader)):
#     print((img[0].size(), img[1].size()))
#     break

# %%
# print(img[0].permute(0, 3, 1, 2).size())
# print(img[0].permute(0, 3, 1, 2).double().dtype )

# %%
model = model.float()

# %%
# outs = model(img[0].permute(0, 3, 1, 2).float())
# print(outs.size())

# %%
# # Calculate the total parameters of the model
# print('Model size: {:0.2f} million float parameters'.format(get_parameters_size(model)/1e6))
# args.pretrained = 'model_best_gcn2wayca.pth.tar'
# if os.path.isfile(args.pretrained):
#     print("=> loading checkpoint '{}'".format(args.pretrained))
#     checkpoint = torch.load(args.pretrained)
#     model.load_state_dict(checkpoint['state_dict'])
# else:
#     print("=> no checkpoint found at '{}'".format(args.pretrained))

# %%
test_loader = DataLoader(load_data(training=False), batch_size=batch_size, shuffle=False)  # ,prefetch_factor=2
# Out:
# ...... Test files loading
#
# split train users: 500
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_404/2824572385.py in <module>
# ----> 1 test_loader = DataLoader(load_data(training=False), batch_size=batch_size, shuffle=False)  # ,prefetch_factor=2
#
# /tmp/ipykernel_404/4078755232.py in __init__(self, training)
#     141         else:
#     142             print('\n...... Test files loading\n')
# --> 143             self.vein_list,self.prints_list, self.labels = part_init(istrain=False)
#     144             print('\nTest files loaded ......\n')
#     145
#
# /tmp/ipykernel_404/4078755232.py in part_init(istrain)
#      81 #                 labels.append(i)
#      82     else:
# ---> 83         for i in tqdm.tqdm(range(train_num)):
#      84             for j in range(8,12):
#      85                 r_img = np.array(Image.open(os.path.join(r_img_path, "%04d_"%(i+1)+"%04d.jpg"%(j+1))))
#
# AttributeError: type object 'tqdm' has no attribute 'tqdm'

# %%
for _, img in tqdm.tqdm(enumerate(test_loader)):
    print((img[0].size(), img[1].size()))
    break
print(img[1])

# %%
# ##### HELPER FUNCTION FOR FEATURE EXTRACTION
# # print(model)

# def get_features(name):
#     def hook(model, input, output):
#         features[name] = output.detach()
#     return hook
# ##### REGISTER HOOK
# model.model_print[16].register_forward_hook(get_features('feats'))
# # model.fc1.register_forward_hook(get_features('feats'))

# %%
def test(net,test_loader):
    test_loss = AverageMeter()
    acc = AverageMeter()
    FEATS = []
    GT = []
    features = {}
    with torch.no_grad():
        for batch_idx, img in enumerate(test_loader):
            rbn = img[0].permute(0, 3, 1, 2).to(device, dtype=torch.float)
            label = img[1].to(device)

            output = net(rbn)
            FEATS.append(output.cpu().numpy())
#             FEATS.append(features['feats'].cpu().numpy())
            GT.append(img[1].numpy())

    GCNFEATS = np.concatenate(FEATS)
    GT = np.concatenate(GT)
    print('- feats shape:', GCNFEATS.shape)
    print('- GT shape:', GT.shape)
    from numpy import dot
    from numpy.linalg import norm

    def cossim(a,b):
        return dot(a, b)/(norm(a)*norm(b))

    pred_scores = []
    gt_label = []

    for i in tqdm.tqdm(range(3000)):
        for j in range(i+1,3000):
            # pred_scores.append(final[i,j].detach().cpu().numpy())
            a = cossim(GCNFEATS[i,:],GCNFEATS[j,:])
            pred_scores.append(a)
            gt_label.append(i//6 == j//6)

    pred_scores = np.array(pred_scores)
    gt_label = np.array(gt_label)

    Gen = pred_scores[gt_label]
    Imp = pred_scores[gt_label==False]
    Imp = Imp[np.random.permutation(len(Imp))[:len(Gen)]]


#     import seaborn as sns
#     sns.distplot(Gen,  kde=False, label='Gen')
#     # df =gapminder[gapminder.continent == 'Americas']
#     sns.distplot(Imp,  kde=False,label='Imp')
#     # Plot formatting
#     plt.legend(prop={'size': 12})
#     plt.title('Life Expectancy of Two Continents')
#     plt.xlabel('Life Exp (years)')
#     plt.ylabel('Density')

    from pyeer.eer_info import get_eer_stats
    from pyeer.report import generate_eer_report, export_error_rates
    from pyeer.plot import plot_eer_stats


    # Calculating stats for classifier A
    stats_a = get_eer_stats(Gen, Imp)
    print(stats_a.eer)

    return stats_a.eer

test(net,test_loader)
##### INSPECT FEATURES

# %%
# np.save('FEATS_gcn2wayca.npy', GCNFEATS)

# %%
# FEATSRES18 = np.load('FEATS_res18.npy')
# print(FEATSRES18.shape)
# FEATSRES18 = np.squeeze(FEATSRES18);
# print(FEATSRES18.shape)
# # # NewFEATS = np.dstack((FEATS,FEATSRES18))
# # FEATS = np.concatenate((FEATS,FEATSRES18), axis=1)
# # print(NewFEATS.shape)

# %%
from numpy import dot
from numpy.linalg import norm

def cossim(a,b):
    return dot(a, b)/(norm(a)*norm(b))

pred_scores = []
gt_label = []

for i in tqdm.tqdm(range(3000)):
    for j in range(i+1,3000):
        # pred_scores.append(final[i,j].detach().cpu().numpy())
        a = cossim(GCNFEATS[i,:],GCNFEATS[j,:])
#         b = cossim(FEATSRES18[i,:],FEATSRES18[j,:])
#         pred_scores.append((1.8*a+0.2*b)/2)
        pred_scores.append(a)
#         pred_scores.append(b)
        gt_label.append(i//6 == j//6)
        

# for i in tqdm.tqdm(range(600)):
#         # pred_scores.append(final[i,j].detach().cpu().numpy())
#         pred_scores.append(cossim(FEATS[i,:],FEATS[]))
#         # gt_label.append(i//12 == j//12)
pred_scores = np.array(pred_scores)
gt_label = np.array(gt_label)

# %%
Gen = pred_scores[gt_label]
Imp = pred_scores[gt_label==False]
Imp = Imp[np.random.permutation(len(Imp))[:len(Gen)]]


import seaborn as sns
sns.distplot(Gen,  kde=False, label='Gen')
# df =gapminder[gapminder.continent == 'Americas']
sns.distplot(Imp,  kde=False,label='Imp')
# Plot formatting
plt.legend(prop={'size': 12})
plt.title('Life Expectancy of Two Continents')
plt.xlabel('Life Exp (years)')
plt.ylabel('Density')

from pyeer.eer_info import get_eer_stats
from pyeer.report import generate_eer_report, export_error_rates
from pyeer.plot import plot_eer_stats


# Calculating stats for classifier A
stats_a = get_eer_stats(Gen, Imp)
print(stats_a.eer)

# %%
import numpy as np
import sklearn.metrics

"""
Python compute equal error rate (eer)
ONLY tested on binary classification

:param label: ground-truth label, should be a 1-d list or np.array, each element represents the ground-truth label of one sample
:param pred: model prediction, should be a 1-d list or np.array, each element represents the model prediction of one sample
:param positive_label: the class that is viewed as positive class when computing EER
:return: equal error rate (EER)
"""
def compute_eer(label, pred, positive_label=1):
    # all fpr, tpr, fnr, fnr, threshold are lists (in the format of np.array)
    fpr, tpr, threshold = sklearn.metrics.roc_curve(label, pred)#, positive_label
    fnr = 1 - tpr

    # the threshold of fnr == fpr
    eer_threshold = threshold[np.nanargmin(np.absolute((fnr - fpr)))]

    # theoretically eer from fpr and eer from fnr should be identical but they can be slightly differ in reality
    eer_1 = fpr[np.nanargmin(np.absolute((fnr - fpr)))]
    eer_2 = fnr[np.nanargmin(np.absolute((fnr - fpr)))]

    # return the mean of eer from fpr and from fnr
    eer = (eer_1 + eer_2) / 2
    return eer

eer = compute_eer(gt_label, pred_scores)
print('The equal error rate is {:.3f}'.format(eer))

# %%
del Gen 
del Imp
del pred_scores
del gt_label
del GCNFEATS
del GT
del test_loader
